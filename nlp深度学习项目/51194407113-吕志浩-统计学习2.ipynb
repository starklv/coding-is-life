# %% [markdown]
# # 1 爬取许嵩歌词数据库

# %%
from selenium import webdriver
import time
import json
import pandas as pd
import numpy as np
from selenium.common.exceptions import NoSuchElementException
import requests
import re
# Out:
# 30

# %%
class Spider_wangyiyun(object):
    
    def __init__(self):
        
        self.start_url = 'https://music.163.com/#/search/m/?s=%E8%AE%B8%E5%B5%A9&type=1'
        self.browser = webdriver.Chrome()
        self.data = []
        self.page = 1
       
    def parse_content(self):
        infos = self.browser.find_elements_by_xpath('//div[@class="srchsongst"]/div') ##要用/div,而不是//div,要用绝对路径而不是相对路径
        for info in infos:
            song_id = info.find_element_by_xpath('./div[2]/div/div/a').get_attribute('href').split('=')[-1]
            song = info.find_element_by_xpath('./div[2]/div/div/a/b').text
            try:
                singer = info.find_element_by_xpath('./div[4]/div[@class="text"]/a').text
            except NoSuchElementException:
                singer = info.find_element_by_xpath('./div[4]/div[@class="text"]').text
            album = info.find_element_by_xpath('div[5]/div/a').get_attribute('title')
            self.data.append([song_id,song,singer,album])
        while self.page < 5: #用while循环,不能用for循环
            self.page+=1
            print(self.page)
            ##翻页按钮
            #通过link文字定位元素定位元素,也可以模糊定位
            pages = self.browser.find_element_by_link_text('下一页')
            self.browser.execute_script('arguments[0].click();',pages)
            self.parse_content()
            
    #将爬好的数据保存到csv文件中     
    def save_content(self):
        colname = ['song_id','song','singer','album']
        df=pd.DataFrame(self.data,columns=colname)
        df.to_csv('music.csv',encoding='utf_8_sig',index=False) ##保存为csv文件,删去索引列
        
    ##利用网易云上的歌词API接口爬取歌词
    def get_info(self,id):
        headers = {
          'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36'
}
        res=requests.get('http://music.163.com/api/song/lyric?id={}&lv=1&kv=1&tv=-1'.format(id),headers=headers)
        json_data = json.loads(res.text)
        try:
            lyric = json_data['lrc']['lyric']
            lyric = re.sub('\[.*\]','',lyric)
        except KeyError :
            lyric = ''
        return  str(lyric)
    
    def txt(self):
        data = pd.read_csv('music.csv')
        for i in range(len(data['song_id'])):
            fp = open('XuSong_lyrics.txt'.format(data['song'][i]),'a+',encoding='utf-8')
            fp.write(self.get_info(data['song_id'][i]))
            fp.close()
            
    def run(self):
        self.browser.get(self.start_url)
        self.browser.switch_to.frame('g_iframe')
        self.browser.implicitly_wait(5) #隐式等待,针对所有元素
        self.parse_content()
        self.save_content()
        self.txt()
        
if __name__ == '__main__':        
    apl = Spider_wangyiyun()
    apl.run()
# Out:
# 1449406576 温泉 许嵩 《温泉》
# 167876 有何不可 许嵩 《自定义》
# 167827 素颜 许嵩 《素颜》
# 411214279 雅俗共赏 许嵩 《青年晚报》
# 27646687 玫瑰花的葬礼 许嵩 《许嵩单曲集》
# 167870 如果当时 许嵩 《自定义》
# 167882 清明雨上 许嵩 《自定义》
# 167655 幻听 许嵩 《梦游计》
# 167850 庐州月 许嵩 《寻雾启示》
# 28854182 惊鸿一面 许嵩 《不如吃茶去》
# 167937 断桥残雪 许嵩 《断桥残雪》
# 167873 多余的解释 许嵩 《自定义》
# 167844 灰色头像 许嵩 《寻雾启示》
# 167732 千百度 许嵩 《苏格拉没有底》
# 167691 天龙八部之宿敌 许嵩 《天龙八部之宿敌》
# 167885 城府 许嵩 《自定义》
# 167744 半城烟沙 许嵩 《半城烟沙》
# 167705 想象之中 许嵩 《苏格拉没有底》
# 5255987 你若成风 许嵩 《乐酷》
# 167888 认错 许嵩 《自定义》
# 28802028 山水之间 许嵩 《不如吃茶去》
# 167841 叹服 许嵩 《寻雾启示》
# 167712 拆东墙 许嵩 《苏格拉没有底》
# 402073807 燕归巢 许嵩 《青年晚报》
# 167679 全球变冷 许嵩 《梦游计》
# 167903 我想牵着你的手 许嵩 《我想牵着你的手》
# 167786 南山忆 许嵩 《半城烟沙》
# 167815 情侣装 许嵩 《情侣装》
# 167715 医生 许嵩 《苏格拉没有底》
# 412902950 最佳歌手 许嵩 《青年晚报》

# %% [markdown]
# # 2  数据来源和数据分析

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('E:/lv python/统计学习2论文/music.csv')

# %% [markdown]
# ## 2.1 可视化分析

# %%
kind,count=np.unique(df['album'],return_counts=True) #用unique函数来计算数据中几个不同的id,以及每个id出现的次数
data={'album':kind,'count':count}
data=pd.DataFrame(data)
data = data.loc[data['count']>1,]
data.head()
# Out:
#       album  count
# 0       《V》      7
# 1   《不如吃茶去》      9
# 7      《千古》      2
# 8    《半城烟沙》     16
# 11   《寻宝游戏》      9

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#很关键显示中文
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %%
#统计各张专辑中的单曲数,可见许嵩是一个高产的网络歌手
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(1, 1, 1)  
ax.bar(data['album'],data['count'])
ax.set(title='专辑单曲数')
ax.set_xticklabels(data['album'],rotation=30)
plt.savefig('E:/lv python/统计学习2论文/专辑单曲数.jpg',dpi=400,bbox_inches='tight') #必须得放在plt.show之前
plt.show()

# %%
df.to_csv('E:/lv python/统计学习2论文/music.csv',encoding='utf_8_sig') ##保存为csv文件

# %% [markdown]
# ## 2.2 对歌词进行分词,统计词频,并制作词云

# %%
import jieba
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import jieba.analyse
from PIL import Image

# %%
with open('E:/lv python/统计学习2论文/xusong.txt','r',encoding='utf-8') as f:
    sentences=f.read()
    f.close()

# %%
seg_list = jieba.cut(sentences, cut_all=False)
word_dict={}
for word in seg_list:
    if len(word)>1:
        prev_counts=word_dict.get(word,0)
        word_dict[word]=prev_counts+1

# %%
word=sorted(word_dict.items(),key=lambda item:item[1],reverse=True)
word[:20]
# Out:
# [('什么', 28),
#  ('不是', 26),
#  ('那么', 25),
#  ('没有', 25),
#  ('一个', 25),
#  ('嘟嘟', 24),
#  ('如果', 23),
#  ('是否', 21),
#  ('最后', 21),
#  ('温柔', 20),
#  ('只是', 20),
#  ('妹妹', 20),
#  ('回忆', 19),
#  ('怎么', 18),
#  ('我们', 17),
#  ('当年', 17),
#  ('想象', 16),
#  ('如今', 16),
#  ('快乐', 15),
#  ('现在', 14)]

# %%
bg=np.array(Image.open('star.jpg'))
segDict={k:v for k,v in word}
wordcloud=WordCloud(font_path='E:/lv python/text mining/Part I  Text Mining Basic/simdata/simhei.ttf',
                   max_font_size=60,relative_scaling=.5,mask=bg,background_color='white').fit_words(segDict)
plt.figure(figsize=(20,15))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('E:/lv python/统计学习2论文/歌词词云图.jpg',dpi=400,bbox_inches='tight') #必须得放在plt.show之前
plt.show()
plt.close()

# %% [markdown]
# # 3  构造建模过程

# %%
from mxnet import nd
import random

# %%
#建立字符索引,来方便之后的数据处理
def load_data_xusong_lyrics():
    """Load the XuSong lyric data set (available in the Chinese book)"""
    with open ('E:/lv python/统计学习2论文/xusong.txt',encoding='utf-8') as f:
        corpus_chars = f.read()
        corpus_chars = corpus_chars.replace('\n', ' ').replace('\r', ' ')
        idx_to_char = list(set(corpus_chars))
        char_to_idx = dict([(char, i) for i, char in enumerate(idx_to_char)])
        vocab_size = len(char_to_idx)
        corpus_indices = [char_to_idx[char] for char in corpus_chars]
        return corpus_indices, char_to_idx, idx_to_char, vocab_size

# %%
import d2lzh as d2l
import math
from mxnet import autograd, gluon, init, nd
from mxnet.gluon import loss as gloss, nn, rnn
import time

# %% [markdown]
# ## 3.1 循环网络的从零开始

# %%
#载入许嵩歌词,很关键
(corpus_indices, char_to_idx, idx_to_char, vocab_size)=load_data_xusong_lyrics()

# %% [markdown]
# ###  初始化模型参数

# %%
num_inputs, num_hiddens, num_outputs = vocab_size, 256, vocab_size
ctx = d2l.try_gpu()
print('will use', ctx)

def get_params():
    def _one(shape):
        return nd.random.normal(scale=0.01, shape=shape, ctx=ctx)

    # 隐藏层参数
    W_xh = _one((num_inputs, num_hiddens))
    W_hh = _one((num_hiddens, num_hiddens))
    b_h = nd.zeros(num_hiddens, ctx=ctx)
    # 输出层参数
    W_hq = _one((num_hiddens, num_outputs))
    b_q = nd.zeros(num_outputs, ctx=ctx)
    # 附上梯度
    params = [W_xh, W_hh, b_h, W_hq, b_q]
    for param in params:
        param.attach_grad()
    return params
# Out:
# '分开操数故琴炬街得摆揽数'

# %% [markdown]
# ### 定义模型

# %%
def rnn(inputs, state, params):
    # inputs和outputs皆为num_steps个形状为(batch_size, vocab_size)的矩阵
    W_xh, W_hh, b_h, W_hq, b_q = params
    H, = state
    outputs = []
    for X in inputs:
        H = nd.tanh(nd.dot(X, W_xh) + nd.dot(H, W_hh) + b_h)
        Y = nd.dot(H, W_hq) + b_q
        outputs.append(Y)
    return outputs, (H,)

# %% [markdown]
# ### 相邻采样

# %%
def data_iter_consecutive(corpus_indices, batch_size, num_steps, ctx=None):
    corpus_indices = nd.array(corpus_indices, ctx=ctx)
    data_len = len(corpus_indices)
    batch_len = data_len // batch_size
    indices = corpus_indices[0: batch_size*batch_len].reshape((
        batch_size, batch_len))
    epoch_size = (batch_len - 1) // num_steps
    for i in range(epoch_size):
        i = i * num_steps
        X = indices[:, i: i + num_steps]
        Y = indices[:, i + 1: i + num_steps + 1]
        yield X, Y

# %% [markdown]
# ### 剪裁梯度

# %%
def grad_clipping(params, theta, ctx):
    norm = nd.array([0], ctx)
    for param in params:
        norm += (param.grad ** 2).sum()
    norm = norm.sqrt().asscalar()
    if norm > theta:
        for param in params:
            param.grad[:] *= theta / norm

# %% [markdown]
# ### 定义模型训练函数

# %%
def train_and_predict_rnn(rnn, get_params, init_rnn_state, num_hiddens,
                          vocab_size, ctx, corpus_indices, idx_to_char,
                          char_to_idx, is_random_iter, num_epochs, num_steps,
                          lr, clipping_theta, batch_size, pred_period,
                          pred_len, prefixes):
    if is_random_iter:
        data_iter_fn = d2l.data_iter_random
    else:
        data_iter_fn = d2l.data_iter_consecutive
    params = get_params()
    loss = gloss.SoftmaxCrossEntropyLoss()
    
    for epoch in range(num_epochs):
        if not is_random_iter:  # 如使用相邻采样，在epoch开始时初始化隐藏状态
            state = init_rnn_state(batch_size, num_hiddens, ctx)
        l_sum, n,start=0.0, 0, time.time()
        data_iter = data_iter_fn(corpus_indices, batch_size, num_steps, ctx)
        for X, Y in data_iter:
            if is_random_iter:  # 如使用随机采样，在每个小批量更新前初始化隐藏状态
                state = init_rnn_state(batch_size, num_hiddens, ctx)
            else:  # 否则需要使用detach函数从计算图分离隐藏状态
                for s in state:
                    s.detach()
            with autograd.record():
                inputs = to_onehot(X, vocab_size)
                # outputs有num_steps个形状为(batch_size, vocab_size)的矩阵
                (outputs, state) = rnn(inputs, state, params)
                # 拼接之后形状为(num_steps * batch_size, vocab_size)
                outputs = nd.concat(*outputs, dim=0)
                # Y的形状是(batch_size, num_steps)，转置后再变成长度为
                # batch * num_steps 的向量，这样跟输出的行一一对应
                y = Y.T.reshape((-1,))
                # 使用交叉熵损失计算平均分类误差
                l = loss(outputs, y).mean()
            l.backward()
            grad_clipping(params, clipping_theta, ctx)  # 裁剪梯度
            d2l.sgd(params, lr, 1)  # 因为误差已经取过均值，梯度不用再做平均
            l_sum += l.asscalar() * y.size
            n += y.size

        if (epoch + 1) % pred_period == 0:
            print('epoch %d, perplexity %f, time %.2f sec' % (
                epoch + 1, math.exp(l_sum / n), time.time() - start))
            for prefix in prefixes:
                print(' -', predict_rnn(
                    prefix, pred_len, rnn, params, init_rnn_state,
                    num_hiddens, vocab_size, ctx, idx_to_char, char_to_idx))
                print(y)

# %% [markdown]
# ## 3.2 循环神经网络的简洁实现

# %% [markdown]
# ### 定义模型

# %%
ctx = d2l.try_gpu()
model = d2lzh.RNNModel(rnn_layer, vocab_size)
model.initialize(force_reinit=True, ctx=ctx)
predict_rnn_gluon('分开', 10, model, vocab_size, ctx, idx_to_char, char_to_idx)

# %%
# 本类已保存在d2lzh包中方便以后使用
class RNNModel(nn.Block):
    def __init__(self, rnn_layer, vocab_size, **kwargs):
        super(RNNModel, self).__init__(**kwargs)
        self.rnn = rnn_layer
        self.vocab_size = vocab_size
        self.dense = nn.Dense(vocab_size)

    def forward(self, inputs, state):
        # 将输入转置成(num_steps, batch_size)后获取one-hot向量表示
        X = nd.one_hot(inputs.T, self.vocab_size)
        Y, state = self.rnn(X, state)
        # 全连接层会首先将Y的形状变成(num_steps * batch_size, num_hiddens)，它的输出
        # 形状为(num_steps * batch_size, vocab_size)
        output = self.dense(Y.reshape((-1, Y.shape[-1])))
        return output, state

    def begin_state(self, *args, **kwargs):
        return self.rnn.begin_state(*args, **kwargs)

# %% [markdown]
# ### 训练模型

# %%
# 本函数已保存在d2lzh包中方便以后使用
def predict_rnn_gluon(prefix, num_chars, model, vocab_size, ctx, idx_to_char,
                      char_to_idx):
    # 使用model的成员函数来初始化隐藏状态
    state = model.begin_state(batch_size=1, ctx=ctx)
    output = [char_to_idx[prefix[0]]]
    for t in range(num_chars + len(prefix) - 1):
        X = nd.array([output[-1]], ctx=ctx).reshape((1, 1))
        (Y, state) = model(X, state)  # 前向计算不需要传入模型参数
        if t < len(prefix) - 1:
            output.append(char_to_idx[prefix[t + 1]])
        else:
            output.append(int(Y.argmax(axis=1).asscalar()))
    return ''.join([idx_to_char[i] for i in output])

# %% [markdown]
# ### 预测模型

# %%
num_epochs, batch_size, lr, clipping_theta = 250, 32, 1e2, 1e-2
pred_period, pred_len, prefixes = 50, 50, ['分开', '不分开']
train_and_predict_rnn_gluon(model, num_hiddens, vocab_size, ctx,
                            corpus_indices, idx_to_char, char_to_idx,
                            num_epochs, num_steps, lr, clipping_theta,
                            batch_size, pred_period,pred_len, prefixes)
# Out:
# epoch 50, perplexity 90.851065, time 0.36 sec
#  - 分开 我想你无百度 我该你 化少摇 我想你在百少 我该你 化少你 一少你 百少月 我想你在百少 我该你
#  - 不分开 我们你千奈度 我能你 化少你 百少你 百少你 一少你 百少你的温妹 我在你一忆是我的温 逃离这个有
# epoch 100, perplexity 13.911729, time 0.36 sec
#  - 分开的那么 想葬人 他往日情勾起 我愿意 化浮萍躺湖心 只陪你 泛岁月的涟漪 花香氤 把往日情勾起 我愿
#  - 不分开 不是我的错表 我该庆幸自己有 看 爱有你的习惯 我想牵着你的手 逃离想你的你受 看你在这首已的冷漠
# epoch 150, perplexity 4.498917, time 0.36 sec
#  - 分开的那么 判带我 爱岁月 一起 我的你是曾的选择 最我太叛逆 现在只剩一和 粗夜了到你安旁 把你最爱的
#  - 不分开 不是我心超太清的姑娘 想带我回忆爱我的乐难 爱完了一首就 人果我太间 渡口边最后一面洒下了句点 与
# epoch 200, perplexity 2.504507, time 0.36 sec
#  - 分开的冰活 判带两人 丢给我去承受 想象中 很不同 他年象中一切都和风已不同 我承能 曾经那么心动 你没
#  - 不分开 不能不要的眼线 却轰烈里的主影 昨把分手 还少太住眼看 毫然捧太 读坚你的承诺 想象之人 这次要去
# epoch 250, perplexity 1.967378, time 0.36 sec
#  - 分开的冰冻 埋葬两人 丢给我去承受 想象中 很不同  想象中一切都和 桥上对岁为刀剑 有些灰里是一个夙
#  - 不分开光 你的绝望溢人胸道 我的你 曾经了情的葬 宿不取功名的后洒是接 读不懂塞北的荒野 梅开时节因寂寞而

# %% [markdown]
# ## GRU 门控循环神经网络预测

# %%
num_inputs, num_hiddens, num_outputs = vocab_size, 256, vocab_size
ctx = d2l.try_gpu()

# %%
num_epochs, num_steps, batch_size, lr, clipping_theta = 160, 35, 32, 1e2, 1e-2
pred_period, pred_len, prefixes = 40, 50, ['分开', '不分开']

# %%
gru_layer = rnn.GRU(num_hiddens)
model = d2l.RNNModel(gru_layer, vocab_size)
d2l.train_and_predict_rnn_gluon(model, num_hiddens, vocab_size, ctx,
                                corpus_indices, idx_to_char, char_to_idx,
                                num_epochs, num_steps, lr, clipping_theta,
                                batch_size, pred_period, pred_len, prefixes)
# Out:
# epoch 40, perplexity 172.689897, time 0.52 sec
#  - 分开 我是你的妹的妹 我想你的你的妹妹 我没你的妹妹 我想你的你的妹 我想你的你的妹妹 我没你的妹妹 我
#  - 不分开 我是你的妹的妹 我想你的你的妹妹 我没你的妹妹 我想你的你的妹 我想你的你的妹妹 我没你的妹妹 我
# epoch 80, perplexity 21.310103, time 0.67 sec
#  - 分开 不是我的错 现在认错有没有用 你说你已经不再爱我 我带你回忆曾经爱的爱我 我没有思想准备 可不到你
#  - 不分开的温柔 你带我也不再再爱 我带你回忆曾经爱的爱我 我没有思想准备 可不到你的过去 我爱没有多一点点点
# epoch 120, perplexity 3.059703, time 0.73 sec
#  - 分开 你若是无世界 又出你的外 守经爱情意 一瓢江湖我沉浮 我寻你千百度 又一岁荣枯 可你的不在 认情只
#  - 不分开着的手 和我也该懂太问着那么你 哪色一首情歌歌总是会觉得失落 幻听你在我的耳边轻轻诉说 夜色多温柔
# epoch 160, perplexity 1.260265, time 0.68 sec
#  - 分开 请你若只是我今 何须看你离楼 回忆场各一个 我怎么圈揽 待绝笔墨痕干 寻敌已太晚 月下门童喟叹 昨
#  - 不分开过的温冻 还还是那么爱情 喜开是回离去情满绪 就是回心彷歌装那么很动 整到你不欢 什么都看不是一种情

# %% [markdown]
# ## LSTM 长短期记忆预测

# %%
num_inputs, num_hiddens, num_outputs = vocab_size, 256, vocab_size
ctx = d2l.try_gpu()

# %%
num_epochs, num_steps, batch_size, lr, clipping_theta = 160, 35, 32, 1e2, 1e-2
pred_period, pred_len, prefixes = 40, 50, ['分开', '不分开']

# %%
lstm_layer = rnn.LSTM(num_hiddens)
model = d2l.RNNModel(lstm_layer, vocab_size)
d2l.train_and_predict_rnn_gluon(model, num_hiddens, vocab_size, ctx,
                                corpus_indices, idx_to_char, char_to_idx,
                                num_epochs, num_steps, lr, clipping_theta,
                                batch_size, pred_period, pred_len, prefixes)
# Out:
# epoch 40, perplexity 241.253236, time 0.50 sec
#  - 分开 我是你的 我的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的
#  - 不分开 我是你的 我的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的
# epoch 80, perplexity 65.750501, time 0.55 sec
#  - 分开 你在化的你的妹柔 我想你 你无你的奈 我想你的你的爱柔 我想你的你的妹 是是你无你的爱 是是你的你
#  - 不分开 我今你的奈的妹择 你想你的你的妹 是是你无你的手 是我在你的技柔 我想你的你的选择 我想你的你的妹
# epoch 120, perplexity 13.317761, time 0.56 sec
#  - 分开有多弱 我说你回忆曾泪的你的分情 不是每的表情 没有说心间 什么时就我自面 我寻你已百度 又情情荣枯
#  - 不分开你的你 太后了喜冰 没有了错不 什么时 把往同 我想你的笑丽 一个的个破歌 把你的星里 一人的童枯
# epoch 160, perplexity 3.733622, time 0.69 sec
#  - 分开去全无你 我承服不想 现在我的错 认该在在不你一起下下 喜经看看眼眼是否着装装侣落一起 你的风情表人
#  - 不分开你却无感情 落怕能光很一点点微着 如贴活的交流一页页寂寂寂难夜 太什么是软弱 太颓唐是折磨 我该怎么

# %% [markdown]
# # 4 调参过程-选择GRU模型

# %%
#主要是对num_steps，batch_size，clipping_rate，num_epochs,lr这5个参数进行调整
#batch_size:每个小批量的样本数
#num_epochs:迭代次数
#clipping_theta:裁剪梯度
#lr:学习率
#num_steps:每个样本所包含的时间步数

# %%
num_inputs, num_hiddens, num_outputs = vocab_size, 256, vocab_size
ctx = d2l.try_gpu()

# %%
num_epochs, num_steps, batch_size, lr, clipping_theta = 250, 35, 32, 1e2, 1e-2
pred_period, pred_len, prefixes = 50, 50, ['分开', '不分开']

# %%
gru_layer = rnn.GRU(num_hiddens)
model = d2l.RNNModel(gru_layer, vocab_size)
d2l.train_and_predict_rnn_gluon(model, num_hiddens, vocab_size, ctx,
                                corpus_indices, idx_to_char, char_to_idx,
                                num_epochs, num_steps, lr, clipping_theta,
                                batch_size, pred_period, pred_len, prefixes)

# %% [markdown]
# ## 4.1  先确定循环周期次数,num_epochs

# %%
#如果随着num_epochs的增加，困惑度perplexity在一定迭代次数内变化很小，就可以停止迭代.

# %%
start=time.time()
for num_epochs in np.arange(200,400,50):
        num_steps, batch_size,clipping_theta,lr= 35, 32, 1e-2,80
        pred_period, pred_len, prefixes = 50, 50, ['分开', '不分开']
        gru_layer = rnn.GRU(num_hiddens)
        model = d2l.RNNModel(gru_layer, vocab_size)
        print('lr: {0} num_epochs: {1}'.format(lr,num_epochs))
        d2l.train_and_predict_rnn_gluon(model, num_hiddens, vocab_size, ctx,
                                corpus_indices, idx_to_char, char_to_idx,
                                num_epochs, num_steps, lr, clipping_theta,
                                batch_size, pred_period, pred_len, prefixes)
print('{:.2f} sec'.format(time.time()-start))
# Out:
# lr: 80 num_epochs: 200
# epoch 50, perplexity 164.741272, time 0.51 sec
#  - 分开 我是你的妹 我在你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你
#  - 不分开 我是你的妹妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想
# epoch 100, perplexity 23.079436, time 0.73 sec
#  - 分开你快乐 我是你无奈的选择 我在担心你是否误会 我没有思想准备 我爱情玩转的如此 你只是我的妹妹 妹妹
#  - 不分开我的温柔 布说你在我的妹妹轻轻离说 我是劝成这里 我不会会有没有用 你说你已经爱么爱我 我带你回忆曾
# epoch 150, perplexity 3.483355, time 0.67 sec
#  - 分开了些手 我的你 想牵中 这人的时不复那么不同 我承认 曾经那么心动 你没想象中那么恋旧 回忆唤不回你
# epoch 200, perplexity 1.328239, time 1.37 sec
#  - 分开你安无多新新的电影 虽然苦 他不干 没有要模糊了 他不是你穿道不再再再你 我在台上已经开始感动 整个
#  - 不分开时影我的创作 布局谋篇像本悲情小说 你太擅长表演 表情淡漠反倒有催泪效果 我在台下已经开始感动 整个
# epoch 250, perplexity 1.067198, time 0.68 sec
#  - 分开你安无柔 为你唱然的歌我 是现在一种心幸 你融化了歌 待服笼血痕染 宿把太来 转世月下 金戈铁马 替
#  - 不分开时影我的创作 布局谋篇像本悲情小说 你太擅长表演 表情淡漠反倒有催泪效果 我在台下已经开始感动 整个
# epoch 300, perplexity 1.036924, time 0.68 sec
#  - 分开你安无柔 为你唱这首歌没有什么风格 它仅仅代表着我想给你快乐 为你解冻冰河为你做一只扑火的飞蛾 没有
#  - 不分开时里我的创 布局谋篇像本悲情小说 你太擅长表演 表情淡漠反倒有催泪效果 我在台下已经开始感动 整个世
# lr: 80 num_epochs: 350
# epoch 50, perplexity 168.349331, time 0.70 sec
#  - 分开 我是你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我
#  - 不分开 我是你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我
# epoch 100, perplexity 22.855469, time 1.35 sec
#  - 分开 我今你的百度 我幻化成雨 爱锁在眉间 一个人的时丽 我寻你千百度 我该化成雨 你在化成雨 爱锁在眉
#  - 不分开过的脆弱 你的挽心情侣 你不会爱的折择 是否这笨 还是会上的选丽 是否这的你 还在心上 没想牵你 曾
# epoch 150, perplexity 3.549475, time 0.69 sec
#  - 分开爱的那么多由 在你的心里 早已设计好 什么时间把我丢掉 我叹服你的技巧 把爱情玩转的如此花哨 可你的
#  - 不分开手 我承认这样 我幻化成雨 守护你身边 一笑为红颜 你若化成风 我幻化成雨 爱锁在眉间 似水往昔浮流
# epoch 200, perplexity 1.351686, time 0.68 sec
#  - 分开爱着的你 残朵停的呼礼 埋入深深爱着的你 残朵停止呼吸 渗入大地 没人会注意 一片小雨滴 陪着我等天
#  - 不分开手 我还有这种 庸俗的情结 可他还是在你心里边 偶尔梦中还窜到嘴边 其实我也能够了解 心碎一旦到过极
# epoch 250, perplexity 1.061972, time 1.35 sec
#  - 分开爱着的你 不朵你止止一个为出看 ho 地天太寒 我们着着的遇局 是现在这样没红眼 因你而起的一泓喜悲
#  - 不分开时手 我用你 曾经有像空泪 我该想住你隔壁 傻站在你家楼下 抬起头数乌云 如果场景里出现一架钢琴 我
# epoch 300, perplexity 1.036880, time 0.68 sec
#  - 分开爱着的情论 心情的歌艺所以回情紧跟潮流的妹妹和我一起 和妹妹说说笑笑 缓释最近糟糕心绪 在下一个转角
#  - 不分开手手 我用之 表流鲜躺湖堤 只陪你 泛岁月的涟漪 古木檀香小筑 经文诵得缓 锦服华裳一炬 粗袖如心宽
# epoch 350, perplexity 1.028214, time 0.67 sec
#  - 分开爱着的年 残朵停的那路 又入化了我求力 嘟嘟嘟嘟嘟嘟嘟 嘟嘟前尘却痴拆 飞过时空渐宿醒 迢迢年华谁老
#  - 不分开手手 我用你回忆也快要执边 独如谋篇 简留空想给你 一样荣枯天注 红雨了泼泛起了回忆怎么潜 你美目如
# 883.85 sec

# %%
#最优的循环周期数num_epochs为300,随着epochs的增大,困惑度perplexity并没有明显的下降,所以可以停止Epoch
# Out:
# 0.01 sec

# %% [markdown]
# ## 4.2 调整学习率lr和batch_size批量大小

# %%
#lr:学习率直接影响模型的收敛状态,过大则导致模型不收敛,过小则导致模型收敛特别慢
#batch_size:每个小批量的样本数,大的batch_size减少训练时间,提高稳定性,导致模型泛化能力下降;
#小的batch_size会增加训练时间,但得到的模型泛化能力较好

# %%
start=time.time()
for lr in np.arange(80,130,10):
     for batch_size in np.logspace(4,8,5,endpoint=True,base=2)::
        num_steps,clipping_theta,num_epochs= 35, 1e-2,300
        pred_period, pred_len, prefixes = 50, 50, ['分开', '不分开']
        gru_layer = rnn.GRU(num_hiddens)
        model = d2l.RNNModel(gru_layer, vocab_size)
        print('lr: {0} batch_size: {1}'.format(lr,int(batch_size)))
        d2l.train_and_predict_rnn_gluon(model, num_hiddens, vocab_size, ctx,
                                corpus_indices, idx_to_char, char_to_idx,
                                num_epochs, num_steps, lr, clipping_theta,
                                int(batch_size), pred_period, pred_len, prefixes)
print('{:.2f} sec'.format(time.time()-start))
# Out:
# lr: 80 batch_size: 16
# epoch 50, perplexity 35.146734, time 0.85 sec
#  - 分开 我没有一个个人 我爱的有多蠢 我该这 把不会 我想牵成雨 我幻化成雨 我幻化成雨 我幻化成雨 我幻
#  - 不分开 我没有一个个人 我爱的有多蠢 我该这 把不会 我想牵成雨 我幻化成雨 我幻化成雨 我幻化成雨 我幻
# epoch 100, perplexity 1.912233, time 0.82 sec
#  - 分开 谁的时边 可情法肠 叹一句当时只道是寻常 庐州月光 梨花雨凉 如今的你又在谁的身旁 家乡月光 深深
#  - 不分开过 如果一个人听歌总是会觉得失落 幻听你在我的耳边轻轻诉说 夜色多温柔 你有多爱我 如今一个人听歌总
# epoch 150, perplexity 1.073364, time 1.01 sec
#  - 分开 谁的城畏 可情法肠 可是一天情静静谁会传光动 挣的并不快 但人熟地熟 还算落得个自在 掌柜的小破酒
#  - 不分开事 如果是否灰小样 我去想住你隔壁 傻站在你家楼下 抬起头数乌云 如果场景里出现一架钢琴 我会唱歌给
# epoch 200, perplexity 1.039886, time 0.94 sec
#  - 分开 谁为我 添两件 三四更雪 风不减 吹袭一夜 只是可怜 瘦马未得好歇 怅然入梦 梦几月 醒几年 往事
#  - 不分开事 又是我也不太清楚 可他是一种s觉 当我而起的告别 是现在这样 红水为你万一分洒 你若化成风 我幻
# epoch 250, perplexity 1.039309, time 0.83 sec
#  - 分开 谁为我 添两件 三四更雪 风不减 吹袭一夜 只是可怜 瘦马未得好歇 怅然入梦 梦几月 醒几年 往事
#  - 不分开事 如果爱间 谁在我望你用己的迹 我曾经苦给你的歌 我爱不住多一个夙 曾州的歌 我飘几眼 他想当你的
#  - 分开 我们不会 你是我心上 我是你无奈的选择 我想牵着你的手 两个人的葬礼 埋葬深的你 太乐的伤 两个人
#  - 不分开 我叹服你的技巧 把这个解释你无所谓 我没有思想 你说我在我的你 两个人 你无轻的美丽 我想牵着你的
# epoch 100, perplexity 1.405709, time 1.09 sec
#  - 分开 谁为我 添两件 三四红雪 风不减 吹袭一夜 只是可怜 瘦马未得好歇 怅然入梦 梦几月 醒几年 往事
#  - 不分开 她菜叹 如坠轮回静买悄悄 半柜的小破酒馆被人拆了东墙 后来有人看见他 其实这场比的想咒 每个人都害
# epoch 150, perplexity 1.053582, time 1.03 sec
#  - 分开 谁为我 添两件 三四更雪 风不减 吹袭一夜 只是可怜 瘦马未得好歇 怅然入梦 梦几月 醒几年 往事
#  - 不分开 她只是我的妹妹 妹妹说紫色很有韵味 她只是我的妹妹 我在担心你是否误会 她只是我的妹妹 对这个解释
# epoch 200, perplexity 1.043402, time 1.05 sec
#  - 分开 谁为我 添两件 三四更雪 风不减 吹袭一夜 只是可怜 瘦马未得好歇 怅然入梦 梦几月 醒几年 往事
#  - 不分开情 手得e 雨坠了 视线要模糊了 此时感觉到你的重要 爱走了 心走了 你说你要走了 我为你唱最后的古
# epoch 250, perplexity 1.039943, time 1.03 sec
#  - 分开 谁为我 添两件 三四更雪 风不减 吹袭一夜 只是可怜 瘦马未得好歇 怅然入梦 梦几月 醒几年 往事
#  - 不分开情 不是模仿你的习 是不再看那么感 缠or my Gui 乘一叶扁舟入景随风望江畔渔火 转竹林深处残
# epoch 300, perplexity 1.039281, time 1.03 sec
#  - 分开 谁为我 添两件 三四更雪 风不减 吹袭一夜 只是可怜 瘦马未得好歇 怅然入梦 梦几月 醒几年 往事
#  - 不分开  代叹夜部了一点桥八 快乐的海枯又石烂 抵不过你最后一句好聚好散 能不能 当成彩排 行同陌路的结局
# lr: 90 batch_size: 32
# epoch 50, perplexity 140.062702, time 0.68 sec
#  - 分开 你在你在你的妹 我想你在你的妹 我想你在你的妹 我想你在你的妹 我想你在你的妹 我想你在你的妹 我
#  - 不分开 你在你在你的妹 我想你在你的妹 我想你在你的妹 我想你在你的妹 我想你在你的妹 我想你在你的妹 我
# epoch 100, perplexity 13.232780, time 0.68 sec
#  - 分开 你的城府有多深 我爱的有多蠢 不想再出 你无不要美的情 是我的城府有多深 我爱的有多蠢 不想再出
#  - 不分开的你 不是那么那么装都有多多情侣 不是模仿你的习惯就能离你更近 太坚强是软弱 太颓唐是折磨 我该意
# epoch 150, perplexity 2.194607, time 0.68 sec
#  - 分开那么风 梦桥风 声坠了 拈花一朵 如果能够多一点点微笑 生命也会多一点点美好 何必活的那么冷酷寂寥
#  - 不分开的你题 却若夜两多少的冷桥 撑经我也在太作 何绕我带色太后 你放化了多少的忧愁或许只有我能懂 你轻轻
# epoch 200, perplexity 1.138452, time 1.35 sec
#  - 分开时无起去我寻望 如果有看不见他都雪背到行囊暗夜离开 丢下老 丢下少 他是否也曾无奈 一去若回来 老家
的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的
#  - 不分开的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的
# epoch 100, perplexity 338.653963, time 0.27 sec
#  - 分开的的的你的的的你的的的你的的的你的的的你的的的你的的的你的的的你的的的你的的的你的的的你的的的你的的
#  - 不分开的的你的的的你的的的你的的的你的的的你的的的你的的的你的的的你的的的你的的的你的的的你的的的你的的的
# epoch 150, perplexity 318.268266, time 0.58 sec
#  - 分开的 我你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你
#  - 不分开你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的你的
# epoch 200, perplexity 294.549824, time 0.57 sec
#  - 分开的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的
#  - 不分开的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的
# epoch 250, perplexity 268.113053, time 0.58 sec
#  - 分开 我的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你
#  - 不分开 我的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你
# epoch 300, perplexity 233.095213, time 0.57 sec
#  - 分开 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的
#  - 不分开 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的
# lr: 110 batch_size: 16
# epoch 50, perplexity 7.259294, time 1.08 sec
#  - 分开了云弱 不会多一点点歌俗的很后 如果能够多一点点微笑 快乐也会多一点点围绕 不要等到全球变冷才觉不妙
#  - 不分开得侣 不是模仿你的习惯就能离你更近 太坚强是软弱 太颓唐是折磨 我该怎么整理 你说过了爱不是浪漫 我
# epoch 100, perplexity 1.116625, time 1.05 sec
#  - 分开了爱 是否每一个美都醒来都多难 是否每一次成熟都都都难忘 落笔 表然中人的小惯 落花雨 可深走看 金
#  - 不分开忘动 不是穿上情侣装就可以装情侣 不是模仿你的习惯就能离你更近 太坚强是软弱 太颓唐是折磨 我该怎么
# epoch 150, perplexity 1.043626, time 1.02 sec
#  - 分开了谁 为你辗转 我再服认下错轮话话抱 多说迷喜的道咒 都绕是一种寂去 桥红r you 表情平静静祖内
#  - 不分开 为你的世冻已经冷漠 全是我的错 现在认错有没有用 你说你已经不再爱我 我带你回忆曾经快乐的时空 你
# epoch 200, perplexity 1.042509, time 1.06 sec
#  - 分开 谁为我 添两件 三四更雪 风不减 吹袭一夜 只是可怜 瘦马未得好歇 怅然入梦 梦几月 醒几年 往事
#  - 不分开 我叹服你的技巧 把爱情玩转的如此花哨 可你的内心 不配你的外表 我该庆幸自己成功地 脱逃 我也知道
# epoch 250, perplexity 1.037784, time 1.02 sec
#  - 分开 谁为我 添两件 三四更雪 风不减 吹袭一夜 只是可怜 瘦马未得好歇 怅然入梦 梦几月 醒几年 往事
#  - 不分开 掌柜的小破酒馆被人拆了东墙 后来衙门说按一平米八吊钱来跟他折算 他不干 他不干 百年招牌祖祖辈辈流
# epoch 300, perplexity 1.040815, time 1.02 sec
#  - 分开 谁为我 添两件 三四更雪 风不减 吹袭一夜 只是可怜 瘦马未得好歇 怅然入梦 梦几月 醒几年 往事
#  - 不分开 你没无色 那么绝季 可是我的错 现在认错有没有用 你说你已经不再爱我 我带你回忆曾经快乐的时空 你
# lr: 110 batch_size: 32
# epoch 50, perplexity 88.827595, time 1.35 sec
#  - 分开 我没有有多么 你说你在百忆 我想你最百忆 我想你最百的选择 你说你唱忆爱的妹妹 你说你在百忆 我想
#  - 不分开 我没有有多么爱 你说你唱忆爱的妹妹 你说你在百忆 我想你最百忆 我想你最百的选择 你说你唱忆爱的妹
# epoch 100, perplexity 4.585658, time 0.68 sec
#  - 分开 如今一个人听歌总是会觉得失过 爱听不在这里我却还没走脱 列表里的歌 随过往流动 一个人的时候 偷偷
#  - 不分开这这里 我们意嘴给你健康 我也没那种 庸俗的情结 可他还是在你心里边 偶尔梦中还窜到嘴边 其实我也不
# epoch 150, perplexity 1.208802, time 0.68 sec
#  - 分开 烟波里久违的故乡 别来无恙 你在心上 别来无恙 你在心上 风在淅淅沥沥的雨中 撑伞走过那路口 有人
#  - 不分开这这情情就可以是我能是这么办和 我们不会坚强 会不会颓唐 只留寂寞陪我说说话 不是穿上情侣装就可以装
# epoch 200, perplexity 1.049543, time 1.36 sec
#  - 分开 你若化成风 我幻化成雨 爱锁在眉间 似水往昔浮流年 那天午后 我站在你家门口 你咬咬嘴唇还是说出了
#  - 不分开这这情情就能以以跳动 可你不喜如我再还会 为你唱这首歌没有什么风格 它仅仅代表着我想给你快乐 为你解
# epoch 250, perplexity 1.033422, time 0.69 sec
#  - 分开 你若化成风 我幻化成雨 爱锁在眉间 似水往昔浮流年 乖乖 我的小乖乖 你的样子太可爱 追你的男生每
#  - 不分开这情情情 不想再到全球别 又能是我太过去 你的城府有多深 我爱的有多蠢 不想再问 也无法去恨 毕竟你
# epoch 300, perplexity 1.033241, time 0.68 sec
#  - 分开 你若化成风 我幻化成雨 爱锁在眉间 似水往昔浮流年 那天午后 我站在你家门口 你咬咬嘴唇还是说出了
#  - 不分开这情情情话 不是现也有么演 不必反反复复想太多 每天都要过的更洒 看得透 放得下 拈花一朵 如果能够
# lr: 110 batch_size: 64
# epoch 50, perplexity 242.856888, time 1.14 sec
#  - 分开 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的
#  - 不分开 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的
# epoch 100, perplexity 73.077412, time 0.56 sec
#  - 分开 我想你的错 现在这成有多么 你说你身旁 现在你的错 现在我的错 现在你的错 现在我的错 现在你的错
#  - 不分开 我们化的错 现在我的错 现在我的错 现在你的错 现在我的错 现在你的错 现在我的错 现在你的错 现
# epoch 150, perplexity 11.617192, time 0.55 sec
#  - 分开 如果能够不是会真 我没有想想准备 看你的家 还在认认有没有用 你说你已经不再爱我 我带你回忆曾经互
#  - 不分开的你 残若在在我的妹妹轻轻一笑 你带我回忆爱里互相的温柔 你带我回忆爱里互相的温柔 你带我回忆爱里互
# epoch 200, perplexity 2.903365, time 1.16 sec
#  - 分开 你没想象中那么脆弱 回忆唤不回你的温柔 最后也不是故作冷漠 转过头 我怎么有一滴泪落 我没想象中那
#  - 不分开你的习 太朵停瑶呼吸 渗入大地 没人会注意 一片小雨滴 陪着我等天明 我用这最后一分钟怀念你 我的挽
# epoch 250, perplexity 1.370092, time 0.62 sec
#  - 分开你无所多眉温 不是穿上情侣装就可以装情侣 不是模仿你的习惯就能离你更近 太坚强是软弱 太颓唐是折磨
#  - 不分开你的温柔 最后的海多里温的枷桥 在在我心上 你已化成风 我是你无奈的选择 你只想跟一个好人 我为你戴
# epoch 300, perplexity 1.083529, time 0.55 sec
#  - 分开你安全感 是他让你受了内伤 我努力恢复你健康 我也没那种 庸俗的情结 可他还是在你心里边 偶尔梦中还
#  - 不分开你的笑 太朵停瑶琴起 剥落了忧愁 快乐就在十指相扣 我想牵着你的手 两个人去宇宙 没引力左右 夜光映
# lr: 110 batch_size: 128
# epoch 50, perplexity 342.729409, time 0.93 sec
#  - 分开  我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我
#  - 不分开  我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我
# epoch 100, perplexity 234.856087, time 0.92 sec
#  - 分开 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的
#  - 不分开 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的
# epoch 150, perplexity 134.924953, time 0.44 sec
#  - 分开 我的你 如下 嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟
#  - 不分开 我的城 你的人 我在化 嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟
# epoch 200, perplexity 63.100112, time 0.44 sec
#  - 分开 我在你千奈的选择 是否这个有多么 你说你唱百过 我为你千百度 我幻化成你 如今的你 只是否上 只是
#  - 不分开 我们服你的技妹 我在这个你的眼 是否这个有多么 你说你唱欢你的温柔 我在你无奈的选择 是否这个有多
# epoch 250, perplexity 24.331266, time 0.93 sec
#  - 分开 你说不会有什么 你的城府有多深 我爱的有多蠢 是我太笨 爱是太认错 真的人 不是否认真 曾想牵 你
#  - 不分开 我的你 曾经爱的人 有些人 那天都 你说你的技巧 你在这个有多的人 你说你唱经不再 你的城府有多深
# epoch 300, perplexity 9.761360, time 0.45 sec
#  - 分开 我也没有有感觉 不想再一点点点 当年的歌书难馆 读来又了多一点 是否无心的你是否还在庐阳 一缕一丝
#  - 不分开着 我的挽留还不是会觉了一点 我的挽留 我一直一滴 可不是我心上 却流不出当年 我愿已 化浮萍躺湖心
# lr: 110 batch_size: 256
# epoch 50, perplexity 420.427146, time 0.27 sec
#  - 分开
#  - 不分开
# epoch 100, perplexity 378.565086, time 0.27 sec
#  - 分开
#  - 不分开
# epoch 150, perplexity 342.774682, time 0.57 sec
#  - 分开 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我
#  - 不分开 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我
# epoch 200, perplexity 291.763729, time 0.58 sec
#  - 分开 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我
#  - 不分开 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我
# epoch 250, perplexity 243.896200, time 0.59 sec
#  - 分开 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的
#  - 不分开 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的 我的你的
# epoch 300, perplexity 207.238226, time 0.58 sec
#  - 分开 你是我一个 你的你的你的你 你说你的你的你 你说你的你的你 你说你的你的你 你说你的你的你 你说你
#  - 不分开 你是我一个 你的你的你的你 你说你的你的你 你说你的你的你 你说你的你的你 你说你的你的你 你说你
# lr: 120 batch_size: 16
# epoch 50, perplexity 5.376657, time 1.09 sec
#  - 分开 我寻你千百度 日出到迟暮 一瓢江湖我沉浮 我寻你千百度 日出到你的一泓 我想牵着你的手 两个人去宇
#  - 不分开 我是认无曾经开始 以不是我的妹妹 我在担心你是否误会 她只是我的妹妹 我在担心你是否误会 她只是我
# epoch 100, perplexity 1.087864, time 1.12 sec
#  - 分开 谁为你 恭候走你的生左左 我没想象中那么脆开 整节起形跌宕 人心乱 可又能怎么办 他女人的美丽对比
#  - 不分开 全是一个安静的晚候 撑楼走观爷路的人 有些你一起 你说懂了爱不是浪漫 我的本分给你安全感 是他让你
# epoch 150, perplexity 1.047852, time 1.11 sec
#  - 分开 谁好我 添两件 三四更雪 风不减 吹袭一夜 只是可怜 瘦马未得好歇 怅然入梦 梦几月 醒几年 往事
#  - 不分开了我 我的绝望溢出胸口 是什么 坠落 升空 你灰色头像不会再跳动 暖色的梦变冰凉的枷锁 如果时光倒流
# epoch 200, perplexity 1.046983, time 1.20 sec
#  - 分开 谁好我 添两件 三四更雪 风不减 吹袭一夜 只是可怜 瘦马未得好歇 怅然入梦 梦几月 醒几年 往事
#  - 不分开 我想你一百成热 你的城也还是是真的难) 我摇晃在舞池中央 (那种体态可以想象) 我做我的改变 又何
# epoch 250, perplexity 1.040253, time 1.09 sec
#  - 分开 很好说 他不回他承班 梦i联瑶褪谁舞和一曲 仿佛映当年翩若惊鸿影 谁三言两语撩拨了情意 谁一颦一笑
#  - 不分开了我 你只是劝我手再执动 为你解冻冰河为你做一只扑火的飞蛾 没有什么事情是不值得 为你唱这首歌没有什
# epoch 300, perplexity 1.044013, time 1.04 sec
#  - 分开 你若化成风 我幻化成雨 守护你身边 一笑为红颜 你若化成风 我幻化成雨 爱锁在眉间 似水往昔浮流年
#  - 不分开了我 不是清上情侣装就可以装情侣 不是模仿你的习惯就能离你更近 太坚强是软弱 太颓唐是折磨 我该怎么
# lr: 120 batch_size: 32
# epoch 50, perplexity 64.679055, time 1.35 sec
#  - 分开 我们化成风 你若化成雨 一个人 红浮 嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟
#  - 不分开 我们服你的技巧 是否人 把你的你 曾在认错 还是会得 嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟
# epoch 100, perplexity 2.875908, time 0.68 sec
#  - 分开手手手 又不是当我自受 却不是这么爱 没想太问 也无法去恨 毕竟你是我最爱的人 我曾经的眼变 埋葬深
#  - 不分开这一世界好看可能 我微微的颤抖 那紧张的喉咙 认真讲述了没做的梦 很生动 天空好我的妹妹 对这个一兜
# epoch 150, perplexity 1.107321, time 0.68 sec
#  - 分开 烟波里久违的故乡 别来无恙 你在心上 别来无恙 你在心上 风在淅淅沥沥的雨中 撑伞走过那路口 有人
#  - 不分开 你若无成表 我的天府有多深 我爱的有多蠢 是我太笨 还是太认真 幻想和你过一生 你的城府有多深 我
# epoch 200, perplexity 1.040903, time 1.35 sec
#  - 分开 烟波里久违的故乡 别来无恙 你在心上 雨后江岸天破晓 老舟新客知多少 远山见竹林芳草 晨风抚绿了芭
#  - 不分开 你当无长表 我的天子 用情的人 还是迢认错 幻想和你过一生 你的城府有多深 我爱的有多蠢 不想再问
# epoch 250, perplexity 1.033968, time 0.67 sec
#  - 分开那么什么 我俩唯一合影 你甜美在笑 我叹服你的技巧 把爱情玩转的如此巧妙 在你的心里 早已设计好 什
#  - 不分开 你若化成风 我幻化成雨 守护你身边 一笑为红颜 你若化成风 我幻化成雨 爱锁在眉间 似水往昔浮流年
# epoch 300, perplexity 1.035157, time 0.68 sec
#  - 分开你安全的喜秋 听说幸福 如今的灵错错可认候 如果看你Rose 可不可以给我Chance 不想看时间这
#  - 不分开 你当我的风  我是你无奈的选择 你只想跟一个好人 我为你戴上了戒指 你的笑也还算是那么逼真 我是你
# lr: 120 batch_size: 64
# epoch 50, perplexity 222.458855, time 1.12 sec
#  - 分开 ho 距离你买无奈 是否还会想起过 当年边静沐暖阳 烟波里久违的故乡 别来无恙 你在不住 别是会人
#  - 不分开这 就是我也这奈界 没有感迟暮 可留就在十指 我是你无奈的选择 你只想跟一个好人 我为你戴上了戒指
# lr: 120 batch_size: 256
# epoch 50, perplexity 422.224026, time 0.58 sec
#  - 分开
#  - 不分开
# epoch 100, perplexity 378.107940, time 0.58 sec
#  - 分开
#  - 不分开
# epoch 150, perplexity 337.557176, time 0.27 sec
#  - 分开 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我
#  - 不分开 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我
# epoch 200, perplexity 284.205425, time 0.27 sec
#  - 分开 我是你的 我你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你
#  - 不分开 我是你的 我你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你的 你
# epoch 250, perplexity 230.490550, time 0.57 sec
#  - 分开 我是你的你的 我的你的你的 我是你的你的 我的你的你的 我是你的你的 我的你的你的 我是你的你的
#  - 不分开 我是你的你的 我的你的你的 我是你的你的 我的你的你的 我是你的你的 我的你的你的 我是你的你的
# epoch 300, perplexity 195.286546, time 0.27 sec
#  - 分开 我的你的你的妹 我是我的你的妹 我是我的你的你的 你的你的你的你 我是我的你的妹 我是我的你的你的
#  - 不分开 我的你的你的妹 我是我的你的你的 你的你的你的你 我是我的你的妹 我是我的你的你的 你的你的你的你
# 5523.50 sec

# %%
#最优的batch_size为32,lr为100

# %% [markdown]
# ## 4.3 调整剪裁梯度clipping_theta和num_steps时间步数

# %%
#clipping_theta:裁剪后的梯度的L2范数不超过theta
#num_steps:时间步数

# %%
start=time.time()
for clipping_theta in [0.005,0.01,0.05]:
    for num_steps in np.arange(30,50,5):
        lr,num_epochs,batch_size= 100,300,32
        pred_period, pred_len, prefixes = 50, 50, ['分开', '不分开']
        gru_layer = rnn.GRU(num_hiddens)
        model = d2l.RNNModel(gru_layer, vocab_size)
        print('clipping_theta: {0} num_steps: {1}'.format(clipping_theta,num_steps))
        d2l.train_and_predict_rnn_gluon(model, num_hiddens, vocab_size, ctx,
                                corpus_indices, idx_to_char, char_to_idx,
                                num_epochs, num_steps, lr, clipping_theta,
                                batch_size, pred_period, pred_len, prefixes)
print('{:.2f} sec'.format(time.time()-start))
# Out:
# clipping_theta: 0.005 num_steps: 30
# epoch 50, perplexity 255.446047, time 0.50 sec
#  - 分开 我是你的你的 我是你的你的 我是你的你的 我是你的你的 我是你的你的 我是你的你的 我是你的你的
#  - 不分开 我是你的你的 我是你的你的 我是你的你的 我是你的你的 我是你的你的 我是你的你的 我是你的你的
# epoch 100, perplexity 90.075588, time 0.58 sec
#  - 分开 我没有有有 我在你的错 我在你的你 我的你的有妹 我想你的手 我在你的你 我在你的妹妹 我想你的你
#  - 不分开 我在你的妹妹 我不是我的妹妹 我想你的手 我在你的你 我在你的妹妹 我想你的你 如今的你 我在你的
# epoch 150, perplexity 21.693839, time 0.50 sec
#  - 分开 你若化成风 我幻化成雨 我幻化成雨 爱锁在眉间 似水往昔浮 我今化成雨 我幻你的孤单 我该庆 连浮
#  - 不分开 不是我心上 没人设的人丽 我该庆 连浮萍躺 心情的人 两情的酒 两情的酒 两情的人 两情的酒 两情
# epoch 200, perplexity 6.182316, time 0.53 sec
#  - 分开 那天月 月下了 拈花一句人不道 那柜的小破酒馆被人拆了东墙 后来有人有人他着小觉 谁一颦一笑摇曳了
#  - 不分开你的手 快局后的交流 又入说你在天口 傻你最已的歌翼轻人 在经人的温柔 在真的时结 可你在我的技单
# epoch 250, perplexity 2.590655, time 0.52 sec
#  - 分开 与你若只是我 爱的好美 可他还在这一生 有些人去宇宙 没引力左右 夜光映出你的温柔 我想牵着你的手
#  - 不分开这开情赏 我命化成求惟你 年少初喜天在我心 多不在穿手 我们化成雨 一个人的时候 偷偷看你的微博 你
# epoch 300, perplexity 1.475298, time 0.54 sec
#  - 分开 烟波月 声逛的涟漪  想象之雨 一瓢江湖喟沉婉 汀州烟鹤眺远方 饮一盏岁月飞扬 唱一曲往事飞扬 山
#  - 不分开你的手 逃朵停止呼吸 渗入大地 没人会注意 一片小雨滴 陪着我等天明 我用这最后一分钟怀念你 总是回
# clipping_theta: 0.005 num_steps: 35
# epoch 50, perplexity 280.693949, time 0.68 sec
#  - 分开 我你的你的 我嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟
#  - 不分开 我你的你的 我嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟
# epoch 100, perplexity 126.404986, time 0.68 sec
#  - 分开 我是你的你的妹 我不是你的妹 我不是你的你 我的你的你 我的你的你 我的你 你在你的你 我的你 你
#  - 不分开 我是你的你的妹 我不是你的妹 我不是你的你 我的你的你 我的你的你 我的你 你在你的你 我的你 你
# epoch 150, perplexity 38.341007, time 0.68 sec
#  - 分开 我的城府有多的人 是我是我的妹妹 我在担心你 如今的你的歌 是我在你的技 我是我成奈的选择 你的城
#  - 不分开过 我带你的错 现在认错有 你说你的错 我是化成雨 我幻化成雨 我幻化成雨 我幻化成雨 我幻化成雨
# epoch 200, perplexity 10.994260, time 0.67 sec
#  - 分开 我在你成奈的选择 你只想象中那么脆泪 我没有思中那么脆弱 回忆后不是我 没有爱一个好人 我为你戴上
#  - 不分开手 你若化下冰侣装就 以磨一个月角 你已化了雨 我幻化成雨 我幻化成雨 爱锁在眉间 似水往昔浮流年
# epoch 250, perplexity 4.139607, time 0.69 sec
#  - 分开 那么多要冰深 你的城府有多深 我爱的有多蠢 不想再问 也无法去恨 毕竟你是我最爱的人 我想你千百度
#  - 不分开这场问题题的难弱 还不是那么那么冷弱 是不要 化成雨 拈想牵也人无奈 却流不出当年泪光 庐州的烟书酒
# epoch 300, perplexity 2.069184, time 0.68 sec
#  - 分开 那么多的冰礼哀乐 都是我的错 现在认错有没有用 你说你已经不再爱我 我带你回忆曾经快乐的时空 你只
#  - 不分开这手臂的心情 却不在这下的残单 轰不是否下过雪 你到化了你是否误会 她只是我的妹妹 对这个解释你无所
# clipping_theta: 0.005 num_steps: 40
# epoch 50, perplexity 293.390901, time 0.67 sec
#  - 分开 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我
#  - 不分开 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 我你的 
#  - 不分开手 最下的城枯 不配你的外单 我该庆幸自己成 我爱的有多蠢 是我太笨 还是太认真 幻想和你过一生 你
# clipping_theta: 0.01 num_steps: 30
# epoch 50, perplexity 81.560898, time 0.72 sec
#  - 分开 我没有有多么 我想你的笑 我在化的你 现在我的错 现在我的错 现在我的错 现在我的错 现在我的错
#  - 不分开 我没有多么多么 我没有多么多么 你的城府有多么 我没有多么多么 你的城府有多么 我没有多么多么 你
# epoch 100, perplexity 4.053391, time 0.72 sec
#  - 分开 你若化成风 我幻化成雨 守护你身边 一笑为红颜 你若化成风 我幻化成雨 爱锁在眉间 似水往昔浮流年
#  - 不分开手 我的你留给了泪指 你只在 上了了爱心 可你若只是一个美的妆散 你不是劝我别再执着 全是我的错 现
# epoch 150, perplexity 1.181182, time 0.72 sec
#  - 分开 烟波里久违的故乡 别来无恙 你在心上 雨后江岸天破晓 老舟新客知多少 远山见竹林芳草 晨风抚绿了芭
#  - 不分开时情情就就可以以这里我们 现算了一起成都雅俗的很后 后来衙门说按一平米八吊钱来跟他折算 他不干 他不
# epoch 200, perplexity 1.045642, time 0.71 sec
#  - 分开 与你若只如初见 何须感伤离别 窗透初晓 日照西桥 云自摇 想你当年荷风微摆的衣角 木雕流金 岁月涟
#  - 不分开时情情 我没有思想准备 看到你身旁还有一位 不知道他是谁 昨夜做了一个梦 梦里我们回到手手 喜欢看你
# epoch 250, perplexity 1.033949, time 0.72 sec
#  - 分开 与你若只如初见 何须感伤离别 窗透初晓 日照西桥 云自摇 想你当年荷风微摆的衣角 木雕流金 岁月涟
#  - 不分开时情情 就是我一直美静的问娘 都楼我为何相爱的人不能在一起 你的过去没人知道 想搜索也搜索不到 我俩
# epoch 300, perplexity 1.034944, time 0.74 sec
#  - 分开时步的你 残朵停止呼吸 渗入大地 没人会注意 一片小雨滴 陪着我等天明 我用这最后一分钟怀念你 总是
#  - 不分开时情情就就能不能 夏末彩排 在否陌模糊 一个人的时候 偷偷看你的微博 你转播的歌好耳熟 我们坐一起影
# clipping_theta: 0.01 num_steps: 35
# epoch 50, perplexity 114.599900, time 1.35 sec
#  - 分开 你说你的妹妹 不是我想你的妹妹 不是我想你的妹妹 不是我想你的妹妹 不是我想你的妹妹 不是我想你的
#  - 不分开 你只是我的妹妹 不是我想你的妹妹 不是我想你的妹妹 不是我想你的妹妹 不是我想你的妹妹 不是我想你
# epoch 100, perplexity 7.422798, time 0.67 sec
#  - 分开爱不是爱不是这世 太坚强是软弱 太颓唐是折磨 我该怎么整理你给过的温柔 不是穿上情侣装就可以装情侣
#  - 不分开过 一个青丝一生珍藏 如今的小人在人的人漠 如今一个人听歌总是会觉得失落 不掺任在我的妹妹轻轻诉说
# epoch 150, perplexity 1.487459, time 0.68 sec
#  - 分开爱着的你 残朵停瑶呼吸 渗入大地 没人会注意 一片小雨滴 陪着我等天明 我用这最后一分钟怀念你 我在
#  - 不分开这样 不是穿仿你的习惯就能离你更近 太坚强是软弱 太颓唐是折磨 我该怎么整理你给过的温柔 穿上情侣装
# epoch 200, perplexity 1.066576, time 1.34 sec
#  - 分开爱着的故痛 却听说观不见得得才 就像我一直在找的姑娘 快写一首情歌雅俗共赏 打完字谜还要接着打榜 如
#  - 不分开这这里 我们不会坚强 会不会颓唐 只留寂寞陪我说说话 不是穿上情侣装就可以装情侣 不是模仿你的习惯就
# epoch 250, perplexity 1.045682, time 0.69 sec
#  - 分开解 断桥是否下过雪 我想起着你的壁 Kistory for my Gui 乘一叶扁舟入景随风望江畔渔
#  - 不分开着我碰起 你其实的冰冻 判若两人 丢给我去承受 想象中 很不同  想象中一切都和后来不同 我承认 曾
# epoch 300, perplexity 1.042216, time 0.68 sec
#  - 分开爱着我心面 为你辗转冰侧为你做弃世界有何不可 夏末秋凉里带一点温热 为你解冻冰河为你做一只扑火的飞蛾
#  - 不分开着我碰起 为你辗这冰河为你做一只扑火的飞蛾 没有什么事情是不值得 为你唱这首歌没有什么风格 它仅仅代
# clipping_theta: 0.01 num_steps: 40
# epoch 50, perplexity 130.159191, time 0.67 sec
#  - 分开 我在你的妹妹 我没有有有有么 我没有有多么 我想你的手 我在化么有有有有 我是我的妹妹 我没有有有
#  - 不分开 我是我的妹妹 我没有有有有么 我没有有多么 我想你的手 我在化么有有有有 我是我的妹妹 我没有有有
# epoch 100, perplexity 10.847334, time 1.36 sec
#  - 分开了多的话  想象一首情歌雅的以装 如果能够多一点点微笑 不要等的小变 埋轰烈的喉咙 认真的伤 你无轻
#  - 不分开的温柔 你带我回忆爱里互乐的折磨 你带我的改变 又在这心 别在认认 曾有一句点滴好 我们意 化成萍躺
# epoch 150, perplexity 1.917113, time 1.37 sec
#  - 分开了些无和我的电妹 你带我的冰见 又在担心你 日口边最痕了 嘟你若爱成 我幻化成雨 爱锁在眉间 似水往
#  - 不分开的电影 判若若带着着我 又有一点点个离要 没有什么道 都愈合不完全 我是你无奈的选择 你只想跟一个好
# epoch 200, perplexity 1.103129, time 0.67 sec
#  - 分开 请你少买冰淇淋 天凉就别穿短裙 别再那么淘气 如果有时不那么开心 我愿意将格洛米借给你 你其实明白
#  - 不分开的电悦 判若若金操醇为小班到夜里 ooook 入冬了想给你买一条围巾 怕眼光不行所以叫着紧跟潮流的妹
# epoch 250, perplexity 1.048935, time 0.68 sec
#  - 分开 请你少买冰淇淋 天凉就别穿短裙 别再那么淘气 如果有时不那么开心 我愿意将格洛米借给你 你其实明白
#  - 不分开这的电影 还还是追也太些这苦题出在一起 你的过去没人知道 想搜索也搜索不到 我俩唯一合影 你甜美在笑
# epoch 300, perplexity 1.033315, time 0.71 sec
#  - 分开 那么时去时难泪光 没是我的错 现在认错有没有用 你说你已经不再爱我 我带你回忆曾经快乐的时空 你只
#  - 不分开这的电果 还是那望有情真 不用反匀粉底液 暴雨天 照逛街 偷笑别人花了脸 如果再看你一眼 是否还会有
# clipping_theta: 0.01 num_steps: 45
# epoch 50, perplexity 179.488742, time 1.23 sec
#  - 分开 我是你的你 我在你 你在你 嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟
#  - 不分开 我是你的你 我在你 你在你 嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟
# epoch 100, perplexity 23.839105, time 0.61 sec
#  - 分开 你若化成风 我幻化成雨 我幻化成雨 你在化成雨 你在化成雨 你在化成雨 你在化成雨 你在化成雨 你
#  - 不分开你 我承服你的技巧 把爱情玩转的如此巧 在你的心心 早配你的外表 我该庆幸你是否误会 她只是我的妹妹
# epoch 150, perplexity 3.221011, time 0.60 sec
#  - 分开了行去 你若化成风 我幻化成雨 爱锁在眉间 似水往昔浮流年 如果 我的小乖乖 你的感子太多爱 爱不到
#  - 不分开手 我的你是百不会会感动 哪开看你的笑容 环须在夏日的风 有泡在丛日的后 别来在丛日里后 你不要多的
# epoch 200, perplexity 1.263250, time 1.22 sec
#  - 分开时步去 请桥之下 请欺欺有 都无无马 一谁为红颜 雨打湿了眼眶 年年倚井盼归堂 最怕不觉泪已拆两行
#  - 不分开这手的陪话变 没有什么那事题 有没什么 满到你的我受 想象之中 这次要爱很久 我领略过   你眼里的
# epoch 250, perplexity 1.048577, time 0.62 sec
#  - 分开停步去 请桥之下首步去 你用化了多少的忧愁或许只有我能懂 你轻轻的问我 我有没有点重 可抱住你就不想
#  - 不分开这这的电变 没有那些多人的人 都怪到我心后 喜就初颓唐是心店 我想你戴上了戒指 你的笑也还算是那么逼
# epoch 300, perplexity 1.034622, time 0.60 sec
#  - 分开停步去年年洁秋秋 追忆每些说 你没想住你 一个人的人 偷偷的你 总在在心里 一将为红颜 陪然入梦 梦
#  - 不分开这手的电话 却然总是软弱 爱过感伤离别 窗透初晓 日照西桥 云自摇 想你当年荷风微摆的衣角 木雕流金
# clipping_theta: 0.05 num_steps: 30
# epoch 50, perplexity 1.443049, time 0.71 sec
#  - 分开你一眼 星也爱的葬礼 埋葬深深爱着的你 残朵停止呼吸 渗入大地 没人会注意 一片小雨滴 你若化成风
#  - 不分开着 断悟了爱不是追逐占有 想象之中 这次要悠 如今的飞又看下的枷锁 如果时光倒流我们又能抓得住什么
# epoch 100, perplexity 219.079985, time 1.40 sec
#  - 分开也回么么有点安湖 你说成表情头 不是我们的如桥 不该是我叹服你的外事 以开了你最归太手 还算红烟我最
#  - 不分开 打着我的城我 还用子也还要天分俗 我也没感事念 花手到你的蠢 幻着你是没有么开乐的古择 不为你的外
# epoch 150, perplexity 1067.862484, time 0.72 sec
#  - 分开里星奈的表情难过说说过了说说难奈的冰柔最后里星漠里的选柔最后的冰柔最后来超做里说的表柔只柔的内秋热心
#  - 不分开心翼翼很雨里最后的表情侣里说说说说说说说说过话每情侣难过的妆柔最心痛天候就正心里冰里说说过话每奈的手
# epoch 200, perplexity 153.064904, time 0.71 sec
#  - 分开后一样泪好想牵着你跳动一样泪光下老你给我太超感觉得重着你给我是我怎么感觉泪想下过那么冷人听你没有用多
#  - 不分开后一样就在摇心动一样就当年泪想下过那么冷过那么多一样泪过那么你其给过那么多一样就当年泪想下过那么重过
# epoch 250, perplexity 226.749026, time 0.75 sec
#  - 分开 你没城表着我没怎么多不要容 我怎么有用 太坚不复复复复你的温柔 却来不出复复复复复复 我没怎么有用
#  - 不分开 你没有思我 没有用 我怎么有用 我没有用 我怀念 你没美美美不要 我没有一笑 我怀念 你不在你的笑
# epoch 300, perplexity 100.364918, time 1.03 sec
#  - 分开 不是模仿了脸 若只是否误过的葬礼 埋葬无表演 若只是否误过的美丽 妹妹说紫色的距离月 后来无恙 江
#  - 不分开始的情绪 花开后一个人去年 不是模仿你的心 逃了了些秋 年年招星墙 为你解冻冰凉里我一直夙秋 都愈的
# clipping_theta: 0.05 num_steps: 35
# epoch 50, perplexity 1.355477, time 0.68 sec
#  - 分开了 断言传中 这次要名只是虚妄 三手 一路烟霞 莺飞草长 柳絮纷飞里看见而故乡 不知心上的表演 隔着
#  - 不分开跳动 不是穿上情侣装就可以装情侣 不是天下翼翼就能重演这场电影 我会不会坚强 会不会颓唐 只留寂寞陪
# epoch 100, perplexity 137.253855, time 0.68 sec
#  - 分开 不是我的错 太坚要你R不舞过 残以你的心事 如果了你的妹妹 我该生心里的歌是就清冷唱的人点点个人
#  - 不分开你的恰言 能不到你的情安 还不会他的歌题 像他岁你的难单 流转着香转就回忆就 还是我心一个我是能 有
# epoch 150, perplexity 124.694628, time 1.35 sec
#  - 分开 不是故 把你太多 不是故 现在心 只陪我 害火 我想牵着你 一片踏 当天 三间 一缕都 当时 升空
#  - 不分开 脱花雨 现在心 没引念 一缕雨 一字都 我怎么成 很不住 一起 红雨 升空 一缕都 当天 一路都
# epoch 200, perplexity 1976.885574, time 0.68 sec
#  - 分开的如果 仿的时下 是否的眼 是否下的正不是否的眼 是否也的眼里 却不要思的眼中 在下的表情 转的并不
#  - 不分开 那么成的开弱 一起的表情 是否也没人的作作 怎么思想象中的颤单 是否也的妹妹 又想象中 是否也是会
# epoch 250, perplexity 124.576955, time 0.67 sec
#  - 分开后 搞来了你的眼表 逃不可你的葬妹妹妹妹妹妹妹妹妹妹妹妹妹妹妹妹妹妹妹妹妹妹妹人逃 一只是一个夙人的
#  - 不分开后 你的笑容 那天你的葬惯 逃俗的人去 那些你的眼弱 那天你的葬惯 逃也也也也不如流弱 嘟嘟嘟嘟嘟嘟
# epoch 300, perplexity 116.841385, time 0.67 sec
#  - 分开心 花他嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟
#  - 不分开心 每一曲月光 春花他是折磨 月也没有什么风 嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟
# clipping_theta: 0.05 num_steps: 40
# epoch 50, perplexity 1.367039, time 0.67 sec
#  - 分开你却全感 是一让梦间 可就就在我心浮 我想在你家门口 我爱这最多的什么 最佳抚i 你在心上 儿来无恙
#  - 不分开情侣 我没有何忆 也就笼凉的明中 轰轰烈烈那几年 我怀念 别怀念 怀念也回不到从前 又是一个安静的晚
# epoch 100, perplexity 421.153220, time 1.36 sec
#  - 分开 你的风边 如今 ho里 如今去光 不断去 如今去 不如今 如今去 转的小酒 不知轻心 不如今 都转
#  - 不分开了 什么可 我怎么结这样 我怎么些这了现来 现怎么心 我怎么风 我怎么那这样微微了 我怎么不现转 我
# epoch 150, perplexity 479.358714, time 0.67 sec
#  - 分开一点点得过的手 只是一些就可你身里的人拆 又是一笑 昨天里的姑景 但你最后一个多一点点生 你若化成雨
#  - 不分开始感觉 寻你一生点 指山一生月的歌中 又落之间的人去又都自难 却是一成一生歌 你无化成心的歌开 感觉
# epoch 200, perplexity 554.713469, time 0.67 sec
#  - 分开后一个人要好难情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情
#  - 不分开光 我们这里一个人听歌雅想想装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣
# epoch 250, perplexity 103.919823, time 0.67 sec
#  - 分开着我心上情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情
#  - 不分开你唱这里我等天明雨着我心上情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情侣装情
# epoch 300, perplexity 1269.002651, time 0.68 sec
#  - 分开 幻化成雨 爱锁在人拆了一点点美果 桥果一点围 一笑起舞起的歌礼 比乐一点点美好难过去好一个人 一缕
#  - 不分开 一笑起过一位 人也没有什么潜都还算落得都还算落得都一位一生围 爱锁在失落得难还在心上 一生起去回忆
# clipping_theta: 0.05 num_steps: 45
# epoch 50, perplexity 1.474101, time 0.61 sec
#  - 分开 太事眠像敌错 那天岁要闲考 那么多要寻找 诱惑太多 不坚定就犯错了 与持里鹤的滚烫 真心这里的主题
#  - 不分开重 表情你 天不都似 这下陌成 可红天当时 一将成 万骨枯 多少白发送走黑发 半城烟沙 随风而下 手
# epoch 100, perplexity 124.193274, time 1.22 sec
#  - 分开演 我们不是你的眼边 只是你千美也会过雪 不起你的错也 想象着你的人生 却把你其旁边 我在你的微话
#  - 不分开这 你在台上自己里 我在我想不不住 我有话歌 泪花花雨 我也不喜 月花雨 月下花雨 只花花雨 我在心
# epoch 150, perplexity 1091.944293, time 0.61 sec
#  - 分开的小心的小心的伤心的小心的小心的小心的小心的小心的像想还有多的妹妹妹妹的如此的小心的小心的小心的小心
#  - 不分开的温柔 是否还是否还在这里的温柔的小心的小心的小心的小心的小心的小心的小心的小心的小心的小心的小心的
# epoch 200, perplexity 324.729704, time 0.60 sec
#  - 分开 是否下 可他下 可他下 可他下 可他下 可他下 可他下 可他下 可他下 可他下 可他下 可他下 可
#  - 不分开 每一颦 是他下 不是一生 我幻想 可他光 可他下 可他下 可他下 可他下 可他下 可他下 可他下
# epoch 250, perplexity 66.980937, time 1.22 sec
#  - 分开间 为你辗转的歌没有多蠢冷漠真的选择酒馆多蠢冰懂懂懂的选礼酒馆多懂一个人看你的手中酒真的伤作酒馆里来
#  - 不分开开爱的人在我应意分手中那么多蠢爱的选作多一点点围墙懂他没有没多蠢他是一个人听歌没有什么笑过对不懂懂添
# epoch 300, perplexity 83.686138, time 0.60 sec
#  - 分开后 我该直想给我的妹妹说出了几年 我们最后的姑候 我该庆想给你的温柔 我没想象中那么脆来轻轻轻着我的
#  - 不分开后一点点点点点点点点点点点点点点点点点点点点点点点点一纸温柔 为红雨中那么脆候笑以想起了些笑笑过了些
# 2847.33 sec

# %%
#缩小间距,逐渐中心化调优clipping_theta
num_inputs, num_hiddens, num_outputs = vocab_size, 256, vocab_size
ctx = d2l.try_gpu()
start=time.time()
for clipping_theta in np.arange(0.008,0.012,0.001):
    for num_steps in np.arange(35,50,5):
        lr,num_epochs,batch_size= 100,300,32
        pred_period, pred_len, prefixes = 50, 50, ['分开', '不分开']
        gru_layer = rnn.GRU(num_hiddens)
        model = d2l.RNNModel(gru_layer, vocab_size)
        print('clipping_theta: {0} num_steps: {1}'.format(clipping_theta,num_steps))
        d2l.train_and_predict_rnn_gluon(model, num_hiddens, vocab_size, ctx,
                                corpus_indices, idx_to_char, char_to_idx,
                                num_epochs, num_steps, lr, clipping_theta,
                                batch_size, pred_period, pred_len, prefixes)
print('{:.2f} sec'.format(time.time()-start))
# Out:
# clipping_theta: 0.008 num_steps: 35
# epoch 50, perplexity 166.157587, time 0.52 sec
#  - 分开 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我
#  - 不分开 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我想你的你的妹 我
# epoch 100, perplexity 23.367438, time 0.67 sec
#  - 分开的温柔 却听我的表 现在认错有没有用 你说你的笑 现在认错有没有用 你说你的笑 现在认错有没有用 你
#  - 不分开过 我不是你的技 对不在这间 渡口 你的天 爱情在 只是太多的美丽 我想牵着你的手 逃离这颗星球 不
# epoch 150, perplexity 3.581446, time 0.70 sec
#  - 分开爱那么脆 是否还在人的耳择 我不担心你是否误会 她只是我的妹妹 对这个解释你无所谓 我没有思想准备
#  - 不分开间手 不到你的外表 我该庆幸自己成功 脱逃 我的妹妹妹 我该庆幸自己成功 脱逃 我的妹妹妹 我该庆幸
# epoch 200, perplexity 1.386407, time 0.67 sec
#  - 分开时步别和 腹化里岁月 我们最不完 你和我 曾经有共同爱好 谁的耳边 总有绝句在萦绕 我们俩 用文言文
#  - 不分开间间已已已的风 我们然风风 为我们望你是否误会 她只是我的妹妹 对这个解释你无所谓 我没有思想准备
# epoch 250, perplexity 1.074040, time 0.67 sec
#  - 分开时步深和 桥化月光 洒在心上 月下的你不复当年模样 太多的伤 难诉衷肠 叹一句当时只道是寻常 庐州月
#  - 不分开间的电冻 却这个老事谁后的脸 不能是否下过情的天得 快带一夜人乎极限 多少都就随风我 我有没有种 庸
# epoch 300, perplexity 1.035979, time 0.67 sec
#  - 分开时同深和 腹化月下夕爷都想象 ho 我球知道 落下我好敌自脸 如果再看你一眼 是否还会有感觉 最真实
#  - 不分开这的脆题 却佳总老不自得长这这 什么都被管 什么都看不惯 什么都没力量推翻 学习生存之道又不安 ho
# clipping_theta: 0.008 num_steps: 40
# epoch 50, perplexity 190.236740, time 0.67 sec
#  - 分开 我的你的妹 我在你的你的妹 我是我的你的妹 我是我的你的妹 我是我的你的妹 我是我的你的妹 我是我
#  - 不分开 我的你的妹 我在你的你的妹 我是我的你的妹 我是我的你的妹 我是我的你的妹 我是我的你的妹 我是我
# epoch 150, perplexity 2.849411, time 1.35 sec
#  - 分开了那么梦  我是一个过的冷择 却不是多么过的冷漠 一个人窝在所以太乘) 我没有何很真 寻不到你的天堂
#  - 不分开这电电的我 不是多心情侣 可有我会不爱 这起为红愁 快乐就在十指相扣 我想牵着你的手 两个人去宇宙
# epoch 200, perplexity 1.236237, time 1.35 sec
#  - 分开后 想你少买冰淇淋 天凉就别穿短裙 别再那么淘气 如果有时不那么开心 我愿意将格洛米借给你 你其实明
#  - 不分开这的电情 却还总是不o 爱 爱不会了什么脆 一个瓢窝过一纸彩秋 摇悟了爱不是追逐占有 想象之中 这次
# epoch 250, perplexity 1.055771, time 0.67 sec
#  - 分开后 想你少买冰淇淋 天凉就别穿短裙 别再那么淘气 如果有时不那么开心 我愿意将格洛米借给你 你其实明
#  - 不分开托谁的就是我和你解温 还算爱的葬礼 那紧张的喉咙 认真讲述了没做的梦 很生动 天空好想下雨 我好想住
# epoch 300, perplexity 1.033686, time 0.67 sec
#  - 分开后 断纸是否下过雪 又想起你的脸 若是无缘再见 白堤柳帘垂泪好几遍 那阵子我们的感情出了一些问题 可
#  - 不分开托谁的就果 我希擅这样真 寻找我们爱过的证据 没有人愿意提起 玫瑰花它的过去 今天这里的主题 我把它
# clipping_theta: 0.009000000000000001 num_steps: 45
# epoch 50, perplexity 204.743864, time 1.22 sec
#  - 分开 我的你的你的 我的你的你 我的你的你 我的你的你 我的你的你 我的你的你 我的你的你 我的你的你
#  - 不分开 我的你的你的 我的你的你 我的你的你 我的你的你 我的你的你 我的你的你 我的你的你 我的你的你
# epoch 100, perplexity 40.764010, time 0.60 sec
#  - 分开 我今一个人 我幻化成雨 一个人 我叹你 百经 嘟嘟嘟嘟嘟 嘟嘟嘟嘟嘟 嘟嘟嘟嘟嘟 嘟嘟嘟嘟嘟 嘟嘟
#  - 不分开 我今一个人 我幻化成雨 一个人 我不是 嘟嘟嘟嘟 嘟嘟嘟嘟嘟 嘟嘟嘟嘟嘟 嘟嘟嘟嘟嘟 嘟嘟嘟嘟嘟
# epoch 150, perplexity 5.524043, time 1.22 sec
#  - 分开爱手 你的城府有 深真的眉结 可他还是在你心里边 偶尔梦中还窜到嘴边 其实我也不够真解 何碎头色全球
#  - 不分开这影 不是是否我太爱里轻着一起 你的目去没人 太颓唐是折磨 我该怎么整理你给过的温柔 不是穿上情侣装
# epoch 200, perplexity 1.680495, time 1.22 sec
#  - 分开这几情 与舟新下知糕心 在梅见得面 回忆笼望 金戈铁马 替谁争天下 一将成 万骨枯 多少白发送走黑发
#  - 不分开这情影 可没有些事的冷 不剩在匀间 水中边最后一面洒下了 与你的眼里已早的感不是在一个一首 雅有多些
# epoch 250, perplexity 1.109458, time 0.60 sec
#  - 分开时着我你没有 用说你的冰冻 又想录之中 全部都保有 你灰色头像不会再跳动 哪怕是一句简单的问候 心贴
#  - 不分开这这电 可没那些说记 是我会笨 没有那么有错 毫领保留却信要几忆 我是你无奈的选择 却不是多么爱的人
# epoch 300, perplexity 1.037108, time 1.22 sec
#  - 分开爱着的年活秋奇 如果有那么一点点微笑 入乐也会多一点点围绕 不要等到全球变冷才觉不妙 Vae他有一些
#  - 不分开重 我们没何给你给全 没有那么多难过 请不见 林逛街 偷念也回不到从前 曾经对上的瞬间 难道是一种错
# clipping_theta: 0.010000000000000002 num_steps: 35
# epoch 50, perplexity 115.838257, time 1.34 sec
#  - 分开 我想你的手 我在你的你的选 我想你的手 我在你的你的选 我想你的手 我在你的你的选 我想你的手 我
#  - 不分开 我想你的手妹 我想你的你的选 我想你的手 我在你的你的选 我想你的手 我在你的你的选 我想你的手
# epoch 100, perplexity 7.204593, time 1.34 sec
#  - 分开 你若化成风 我幻化成雨 守护你身边 一笑为红颜 你若化成风 我幻化成雨 爱锁在眉间 似水往昔浮流年
#  - 不分开心的你 不会不会他那么冷漠 想起你的天 太过的忧不不全 爱的爱不太多的冷 我说你回忆如今的恰活 你带
# epoch 150, perplexity 1.441061, time 0.67 sec
#  - 分开了无情 你若化成风 我幻化成雨 守护你身边 一笑为红颜 你若化成风 我幻化成雨 爱锁在眉间 似水往昔
#  - 不分开动 我想你的百冻 柳下闻瑶琴起舞和一曲 仿佛映当年翩若惊鸿影 谁三言两语撩拨了情意 谁一颦一笑摇曳了
# epoch 200, perplexity 1.059066, time 1.34 sec
#  - 分开那些情纯 最后的挽留 没有说出口 我们还是朋友 是那种最遥远的朋友 你给过的温柔 在记录之中 全部都
#  - 不分开动 我承认 曾经那么心动 你没想象中那么恋旧 回忆唤不回你的温柔 最后也不是故作冷漠 转过头 我怎么
# epoch 250, perplexity 1.034583, time 0.67 sec
#  - 分开那些情纯 心开的喜枯 没有说出口 我们还是朋友 是那种最遥远的朋友 你给过的温柔 在记录之中 全部都
#  - 不分开心 你若工作很忙要加班到夜里 ooook 入冬了想给你买一条围巾 怕眼光不行所以叫着紧跟潮流的妹妹和
# epoch 300, perplexity 1.028610, time 0.68 sec
#  - 分开那些情纯 老若停冻 岁月涟漪 七年前封笔 因为我今生挥毫只为你 雨打湿了眼眶 年年倚井盼归堂 最怕不
#  - 不分开着你 没有那么回出回想感到了得障 他是我应该见再下开能是多一级阶钝 我也不会这里的问桥上 如果时不回
# clipping_theta: 0.010000000000000002 num_steps: 40
# epoch 50, perplexity 129.547838, time 1.35 sec
#  - 分开 我想化成你的眼 我在化成你的眼 我在化成你的眼 我在化成你的眼 我在化成你的眼 我在化成你的眼 我
#  - 不分开 我们化成歌 我在化成你的眼 我在化成你的眼 我在化成你的眼 我在化成你的眼 我在化成你的眼 我在化
# epoch 100, perplexity 10.324472, time 0.67 sec
#  - 分开你快乐 为你辗转冰侧为你放弃世界有什么 幻末秋 丢不干 他是否认错受 想象中 把不能住你 真的好美丽
#  - 不分开你 我今服你的技巧 把爱情玩转的如此巧妙 在你的心里 早已设计好 什么时的时丽 偷偷了你的生博 你只
# epoch 150, perplexity 1.797023, time 0.67 sec
#  - 分开你无手 我该俩 曾经那么心动 你没想象中那么恋旧 回忆唤不回你的温柔 最后也不是故作冷漠 转过头 我
#  - 不分开这 这友青熟的表容 轰轰烈香那几年 我怀念 别怀念 怀念也回不到从前 曾经一个安生的晚上 一个人窝在
# epoch 200, perplexity 1.082977, time 1.35 sec
#  - 分开你 那么多的时 你锁又买花风 我去略定   你眼里的温柔热烈以后 你忽然的冰冻 判若两人 丢给我去承
#  - 不分开这 朋友秋凉的眼线 不用抹匀粉底液 暴雨天 照逛街 偷笑别人花了脸 如果再看你一眼 是否还会有感觉
# epoch 250, perplexity 1.041237, time 0.67 sec
#  - 分开你安全感 是他让 曾经那么冷动 我没有那么重备 看到你身旁还有一位 不知道他是谁 那阵子要是回想 我
#  - 不分开这 花开后凉的简容 园轰烈烈那几年 有遗憾 一逛街 我们当你当我的人 两城你的眼神 看起来那么单纯
# epoch 300, perplexity 1.034134, time 1.34 sec
#  - 分开你安全感 是他让你受了内伤 我努力恢复你健康 我也没那种 庸俗的情结 可他还是在你心里边 偶尔梦中还
#  - 不分开了 花开后凉的表容 环绕着香甜的风 有泡在丛林里的温泉神奇疗愈的作用 我微微的颤抖 那紧张的喉咙 认
# clipping_theta: 0.010000000000000002 num_steps: 45
# epoch 50, perplexity 182.240742, time 0.60 sec
#  - 分开 我的你的你的妹 我不是我的你的妹 我不是我的你的妹 我不是我的你的妹 我不是我的你的妹 我不是我的
#  - 不分开 我是我的你的妹 我在你的你的妹 我在你的你的妹 我在你的你的妹 我在你的你的妹 我在你的你的妹 我
# epoch 100, perplexity 24.582494, time 1.22 sec
#  - 分开 我们服你的技巧 把爱情玩转的如此 不要心的交球 剥入了你的难堂 把你的心情 不在你的外 还在你的错
#  - 不分开你 如今一个人听歌总是会觉得难落 不是我的错妹 我在担错你是否误会 她是我的错 现在认错有没有用 你
# epoch 150, perplexity 3.292874, time 0.60 sec
#  - 分开这些去下的深秋 最后的挽留 没有说出口 我们还是朋友 是那种最遥远的朋友 你给过的温柔 在记录烈中
#  - 不分开着你的恰话恰朵 可你解冻冰河为你放弃世界有何不可 夏末秋凉里带一点温热 为你若下过歌 没有多问点倒开
# epoch 200, perplexity 1.291629, time 0.60 sec
#  - 分开那些深的童秋 最后也不能故作冷漠 何必活的那么冷酷寂寥 入夜总为小事而睡不着 如果能够多一点点微笑
#  - 不分开这的电论 你若无无情的眼语 不必力匀才复都而缠 你送我的风景 柳下闻瑶琴起舞和一曲 仿佛映当年翩若惊
# epoch 250, perplexity 1.054342, time 1.22 sec
#  - 分开爱着的你 残朵停止呼吸 渗入大地 没人会注意 一片小雨滴 陪着我等天明 我用这最后一分钟怀念你 总是
#  - 不分开我的妹妹 看你解冻冰河为你做一只扑火的飞蛾 没有什么事情是不值得 为你唱这首歌没有什么风格 它仅仅代
# epoch 300, perplexity 1.036337, time 0.61 sec
#  - 分开爱着的你 残朵停止呼吸 渗入大地 没人会注意 一片小雨滴 陪着我等天明 我用这最后一分钟怀念你 我在
#  - 不分开我的耳妹 柳关闻瑶琴起舞和一曲 仿佛映当年翩若惊鸿影 谁三言两语撩拨了情意 谁一颦一笑摇曳了星云 纸
# clipping_theta: 0.011000000000000003 num_steps: 35
# epoch 50, perplexity 85.892455, time 0.67 sec
#  - 分开 我没有有多么 你说你身奈的选 你说你身奈的选 你说你身奈的选 你说你身奈的选 你说你身奈的选 你说
#  - 不分开 我是你的妹妹 我想你在你的温 我想你在你的温 我想你在你的温 我想你在你的温 我想你在你的温 我想
# epoch 100, perplexity 4.525999, time 1.35 sec
#  - 分开了你 爱的美出还不那的我 有说你过过的温美轻诉说说夜夜色懂算 没有什么说说一笑是是我太何 太坚强是软
#  - 不分开他天天 我幻你的孤单 今生恐去宇宙 那么力左右 老光映出你的温柔 我想牵着你的手 逃离这颗星球 剥落
# epoch 150, perplexity 1.241122, time 1.35 sec
#  - 分开了云影 如今之光 洒在心上 月下的你不复当年模样 太多的伤 难诉衷肠 叹一句当时只道是寻常 庐州月光
#  - 不分开你已天 不再再他 这次清去 如今的你又在谁的身旁 家乡月光 深深烙在我心上 却流不出当年泪光 翻手为
# epoch 200, perplexity 1.044040, time 0.68 sec
#  - 分开时安 我们服你的技巧 把爱情玩转的如此巧妙 在你的心里 早已设计好 什么时间把我丢掉 我叹服你的技巧
#  - 不分开你其天 为你辗转 曾经的眼 苍不同迢迢 又在心上 风在回昔下 幻想牵雨 雨尘往梦 梦断往成飞歇 怅然
# epoch 250, perplexity 1.034774, time 1.35 sec
#  - 分开时安很后 梦竹晚下小残残冬小筑侣始 追忆紧贴的人间 轰轰烈烈那几年 我怀念 别怀念 怀念也回不到从前
#  - 不分开你其世 我承服你的技巧 把爱情玩转的如此巧妙 在你的心里 早已设计好 什么时间把我丢掉 我叹服你的技
# epoch 300, perplexity 1.033135, time 1.35 sec
#  - 分开时安 我会还会坚强 寻不到你的天堂 东瓶西镜放 恨不能遗忘 又是清明雨上 折菊寄到你身旁 把你最爱的
#  - 不分开你一天 我们化好雨 你真没感动 一个人的时候 偷偷看你的微博 你每天做了些什么 我都了然于胸 当时嫌
# clipping_theta: 0.011000000000000003 num_steps: 40
# epoch 50, perplexity 106.052166, time 0.67 sec
#  - 分开 我在化成有多么 我想化成雨 我在化成有一点 我想化成雨 我在化成有一点 我想化成雨 我在化成有一点
#  - 不分开 我是我心成爱的温巧 我没有有多么 我想化成雨 我在化成有一点 我想化成雨 我在化成有一点 我想化成
# epoch 100, perplexity 6.360382, time 1.35 sec
#  - 分开了爱情的小秋 却不是不知那么爱抱 我带你回忆曾经快乐的时空 你只是劝我别再执着 全是我的错 现在认错
#  - 不分开的折妹 妹妹说紫色很懂 可不是多么爱的人 只怪他下手太残忍 改开你一生 我们最最后后后 寻你最爱的歌
# epoch 150, perplexity 1.392157, time 1.34 sec
#  - 分开了几磨 我们意 化文言躺湖心 只陪你 泛岁月的涟漪 落花雨 你飘摇在天地 晚花花的你 看的轻狂 还不
#  - 不分开这这情的电话神还还走走 他不干 他不干 百年招牌祖祖辈辈流传下来 挣的并不快 但人熟地熟 还算落得个
# epoch 200, perplexity 1.058126, time 0.70 sec
#  - 分开了步去的小秋 木雕你走的如心 却不是多么爱的人 只怪他下手太残忍 改变你一生 我们最好的遇见 是现在
#  - 不分开这这的就看上 看不总小风长睡就能梦游 如果和你的笑演 不在抹匀粉底液 暴雨天 照逛街 偷笑别人花了脸
# epoch 250, perplexity 1.040634, time 1.34 sec
#  - 分开了步去去 腹化风雪为刀剑 爱 爱 爱 为了一个夙愿 荒乱中邪正如何辨 飞沙狼烟将乱我 徒有悲添 半城
#  - 不分开这这情的深话 还是那些问情的绪 都是我也不太清楚问题着迟哪的电色 又是一个安静的歌 是我今夜过里 渡
# epoch 300, perplexity 1.035563, time 1.34 sec
#  - 分开了步去的你安目 如色的梦变难凉的枷锁 如果时光倒流我们又能抓得住什么 当我发现所谓醒来其实是另一个梦
#  - 不分开这场电影 我会不会坚强 会不会颓唐 只留寂寞陪我说说话 不是穿上情侣装就可以装情侣 不是模仿你的习惯
# clipping_theta: 0.011000000000000003 num_steps: 45
# epoch 50, perplexity 146.855464, time 0.60 sec
#  - 分开 我是我的妹妹 我想你的妹妹 我想你的妹妹 我想你的妹妹 我想你的妹妹 我想你的妹妹 我想你的妹妹
#  - 不分开 我是我的妹妹 我想你的妹妹 我想你的妹妹 我想你的妹妹 我想你的妹妹 我想你的妹妹 我想你的妹妹
# epoch 100, perplexity 13.360706, time 1.22 sec
#  - 分开的你 残瑰轻色很歌是会多的折磨 我心上 你经轻的美丽 我不是你的爱情 我在担心你是否误会 她只是我的
#  - 不分开你 我叹服你的技巧 把爱情玩转的如此 你只在这里 我幻化成雨 爱锁在眉间 似水的你 还在太认 爱情的
# epoch 150, perplexity 2.116287, time 0.60 sec
#  - 分开时光 一个月琴酒路一曲秋 断经我会能够了解心 分开一个人复懂限的退后 直见走光装像照亮一样 谁一颦一
#  - 不分开你 她只是我的妹妹 妹妹说紫色很有韵味 她只是我的妹妹 我在担心你是否误会 她只是我的妹妹 对这个解
# epoch 200, perplexity 1.116831, time 0.60 sec
#  - 分开时步的梦 每个人懂泛-方念 自晨红言过去掌雨雷 不知花点前雪 可落了地忘 快乐就在别指 我该想住你
#  - 不分开你 她只是我的妹妹 妹妹说紫色很有韵味 她只是我的妹妹 我在担心你是否误会 她只是我的妹妹 对这个解
# epoch 250, perplexity 1.040419, time 1.22 sec
#  - 分开时步的梦 你只是劝上信的问恰 还在一个人静歌总是会觉得失落 幻听你在我的耳边轻轻诉说 夜色多温柔 你
#  - 不分开你 你在我也唱经了里 心碎一旦到过极限 用多少岁月 都愈合不完全 我是你无奈的选择 你只想跟一个好人
# epoch 300, perplexity 1.032847, time 1.22 sec
#  - 分开时步那么多 我今夜何的技择 是现在这样没红眼 因你而起的一泓喜悲 权当年轻留个纪念 清晨回笼做了梦
#  - 不分开给你碰然 如今一个人听歌总是会觉得失落 幻听你在我的耳边轻轻诉说 夜色多温柔 你有多爱我 如今一个人
# 3268.99 sec

# %%
#最优的clipping_theta为0.01,继续调优num_steps
num_inputs, num_hiddens, num_outputs = vocab_size, 256, vocab_size
ctx = d2l.try_gpu()
start=time.time()
for num_steps in np.arange(25,40,5):
        lr,num_epochs,batch_size,clipping_theta= 100,300,32,0.01
        pred_period, pred_len, prefixes = 50, 50, ['分开', '不分开']
        gru_layer = rnn.GRU(num_hiddens)
        model = d2l.RNNModel(gru_layer, vocab_size)
        print('num_steps: {0}'.format(num_steps))
        d2l.train_and_predict_rnn_gluon(model, num_hiddens, vocab_size, ctx,
                                corpus_indices, idx_to_char, char_to_idx,
                                num_epochs, num_steps, lr, clipping_theta,
                                batch_size, pred_period, pred_len, prefixes)
print('{:.2f} sec'.format(time.time()-start))
# Out:
# clipping_theta: 25
# epoch 50, perplexity 42.148738, time 0.55 sec
#  - 分开一点点点 不是我该忆太再 我该担你是否误会 我想你千百度的人 只是我也爱情爱的人 我没有多想那么 我
#  - 不分开我 如果有一个个人 我们没有多一点点点 我想你回忆太再再轻的你 我在你的温柔 我该担着你的手 逃个人
# epoch 100, perplexity 2.135638, time 0.56 sec
#  - 分开时无无绪 如今一个人听歌总是会觉得难过 爱已不在这里我却还没走脱 如果你回头 不要放下我 儿时时点陪
#  - 不分开手手手 幻想你回家见妈指 你只想跟着我的创作 布局谋篇像本悲情小说 你太擅长表演 表情淡漠反倒有催泪
# epoch 150, perplexity 1.072887, time 0.58 sec
#  - 分开时无无 腹化风歌为刀剑 爱里的喜书归巢 沿途的景 牵挂的人 两情迢迢 柳叶桨溅桃花浪 汀州里鹤眺远方
#  - 不分开前手手手手 又天一梦 梦过我们又自己 我想牵你 化成阑珊处 怅仇已不知花光 我站略你唱楼下 抬起了你
# epoch 200, perplexity 1.043536, time 0.59 sec
#  - 分开时无去 腹如风一起成香 请大相餐做 当时映出你的温柔 我想牵着你的手 逃离这颗星球 剥落了忧愁 快乐
#  - 不分开前场电手 不到小间目残就想与你实手 为你辗转反侧为你放弃世界有何不可 夏末秋凉里带一点温热有换季的颜
# epoch 250, perplexity 1.035563, time 0.59 sec
#  - 分开时托无以 我今生何的你去 感现在一种生往 请领悟心oooo  我自念 百文言躺湖堤真 谁的耳边 总有
#  - 不分开问电手 想你回想如初见 何须感伤离别 窗透初晓 日照西桥 云自摇 想你当年荷风微摆的衣角 木雕流金
# epoch 300, perplexity 1.035365, time 0.59 sec
#  - 分开时托无以心 是否每一次成熟都徒增了业障 比痛和痒更多的 是不痛不痒 所以寂寞别同了 此再住你的眼去
#  - 不分开问电手 想想之中中窥照 简单到时间一冲就冲淡 曾经的海枯又石烂 抵不过你最后一句好聚好散 能不能 当
# clipping_theta: 30
# epoch 50, perplexity 81.262111, time 0.71 sec
#  - 分开 我没有有多么 我想你的手 你在化成有一个 我想你的手 你在我的错 你在你的错 我想你的错 我在你的
#  - 不分开 我没有一个人 是我的你 曾在你的错 我想你的错 我在你的错 我在你的错 我在你的错 我在你的错 我
# epoch 100, perplexity 4.087187, time 0.72 sec
#  - 分开你无重的时秋 不是穿上情侣装就可以装情侣 不是模仿你的习惯就能离你更近 太坚强是软弱 太颓唐是折磨
#  - 不分开手 我的你留里的人 是不是这么那么点旧 你和你戴不如今的人活 最后也不是一个冷漠 转说你喜近好何以天
# epoch 150, perplexity 1.178941, time 0.72 sec
#  - 分开去着我和你 这个挥挥你面全和我不觉 如果能夜间一点点微笑 快乐也会多一点点围绕 不要等到全球变冷才觉
#  - 不分开上 太听子熟琴起着眼情的小秋 还告不梳 你在心上 儿来裂传来了谁 for y接藏 表面平静的错 却不
# epoch 200, perplexity 1.046214, time 0.71 sec
#  - 分开去步去我回忆 她只是我的妹妹 妹妹说紫色很有韵味 她只是我的妹妹 我在担心你是否误会 她只是我的妹妹
#  - 不分开你一生为却带一起界着的我 蓝色披风鼓囊着半立方悸动 骑行在泉水小镇下坡有点陡 正好紧贴我背后 和你在
# epoch 250, perplexity 1.035178, time 0.71 sec
#  - 分开去步断 你若化成风 我幻化成雨 守护你身边 一笑为红颜 你若化成风 我幻化成雨 爱锁在眉间 似水往昔
#  - 不分开上情侣 最开了大事谁 一个大寞雅雅俗 在水悟歌代索 血雨天 可又能怎么办 他女人的美丽对比映衬出他的
# epoch 300, perplexity 1.033644, time 0.71 sec
#  - 分开你安全感感 如果花夜时间轮觉 你若化下风着 红雨 距过过我我相己 不是穿上情侣装就可以装情侣 不是模
#  - 不分开上 多的绝活溢带一笑 是否我一直在找的姑娘 快写一首情歌雅俗共赏 打完字谜还要接着打榜 如果胡同弄堂
# clipping_theta: 35
# epoch 50, perplexity 117.033548, time 0.67 sec
#  - 分开 我想你的妹妹 我想你的你的妹 我想你的手 我在你的爱的妹 我想你的手 我在你的爱的妹 我想你的手
#  - 不分开 我没有有有多么 我没有有多的温柔 我没有有多的妹妹 我没有有多的妹妹 我没有有多的妹妹 我没有有多
# epoch 100, perplexity 7.712911, time 0.67 sec
#  - 分开 如果能看你的眼 是否在这样的如此花哨 在你的心里 早已设计动 还算落得个自在 掌柜的小破酒馆被人拆
#  - 不分开的你美的温柔 最后的温柔 没有多爱的结 我该庆幸自己的回忆 你 回上不要装的恋 不到你的笑在 我有没
# epoch 150, perplexity 1.524299, time 0.68 sec
#  - 分开 那么多看爱见了小心翼翼别 你不是劝我别再执着 全是我的错 现在认错有没有用 你说你喜欢如今的生活
#  - 不分开着我的你 残朵闻瑶舞带一点米八 摇起跟就可见让灭 独南夜色下的小桥屋檐 读不懂塞北的荒野 梅开时节因
# epoch 200, perplexity 1.062139, time 0.68 sec
#  - 分开 那果无久 老奉夏名 云自摇 想你当年荷风微摆的衣角 木雕流金 岁月涟漪 七年前封笔 因为我今生挥毫
#  - 不分开着我的你 又如轻的问题 不是我心错 守口边最后一面洒下了句点 与你若只如初见 何须感伤离别 红雨瓢泼
# epoch 250, perplexity 1.038889, time 1.40 sec
#  - 分开 烟波月光 洒在心上 月下的你不复当年模样 太多的伤 难诉衷肠 叹一句当时只道是寻常 庐州月光 梨花
#  - 不分开着我的你 如如再何的你是否安没走柯 我的挽留和出一平米八吊钱来跟他折算 他不干 他不干 百年招牌祖祖
# epoch 300, perplexity 1.033372, time 0.67 sec
#  - 分开爱着的你 残朵停止呼吸 渗入大地 没人会注意 一片小雨滴 陪着我等天明 我用这最后一分钟怀念你 我在
#  - 不分开着我的你 如今的眼变冰凉的枷锁 如果时光倒流我们又能抓得住什么 当我发现所谓醒来其实是另一个梦 你不
# 629.15 sec

# %%
#最优的num_steps为35
#最优参数如下
num_epochs, num_steps, batch_size, lr, clipping_theta = 300, 35, 32, 1e2, 1e-2
pred_period, pred_len, prefixes = 50, 50, ['分开', '不分开']

# %% [markdown]
# # 5 GRU门控循环单元与LSTM长短期记忆之间的区别
#
# ## 1.对memory的控制
# LSTM : 用output gate 控制, 传输给下一个unit
# GRU : 直接传递给下一个unit, 不做任何控制,GRU更节省时间
#
# ## 2.input gate 和reset gate 作用位置不同
# LSTM : 计算new memory $\hat{c}^{(t)}$时,不对上一时刻的信息做任何控制,而是用forget gate独立的实现这一点
# GRU ：计算new memory $\hat{h}^{(t)}$时利用reset gate对上一时刻的信息进行控制.
#
# ## 3.相似
# 最大的相似之处就是,在从$t$到$t-1$的更新时都引入了加法
# 这个加法的好处在于能防止梯度弥散,因此LSTM和GRU都比一般的RNN效果好

# %% [markdown]
# ### 普通RNN模型

# %%
num_epochs, num_steps, batch_size, lr, clipping_theta = 300, 35, 32, 1e2, 1e-2
pred_period, pred_len, prefixes = 50, 50, ['只是', '回忆']
ctx = d2l.try_gpu()
start=time.time()
rnn_layer = rnn.RNN(num_hiddens)
rnn_layer.initialize()
model = d2lzh.RNNModel(rnn_layer, vocab_size)
model.initialize(force_reinit=True, ctx=ctx)
d2lzh.train_and_predict_rnn_gluon(model, num_hiddens, vocab_size, ctx,
                            corpus_indices, idx_to_char, char_to_idx,
                            num_epochs, num_steps, lr, clipping_theta,
                            batch_size, pred_period,pred_len, prefixes)
print('{:.2f} sec'.format(time.time()-start))
# Out:
# epoch 50, perplexity 86.390463, time 14.39 sec
#  - 只是 你若你 百经月 嘟嘟嘟嘟嘟 嘟嘟嘟 嘟嘟嘟嘟嘟 嘟嘟嘟 嘟嘟嘟嘟嘟 嘟嘟嘟 嘟嘟嘟嘟嘟 嘟嘟嘟 嘟
#  - 回忆 你们你 百经月 嘟嘟嘟嘟嘟 嘟嘟嘟 嘟嘟嘟嘟嘟 嘟嘟嘟 嘟嘟嘟嘟嘟 嘟嘟嘟 嘟嘟嘟嘟嘟 嘟嘟嘟 嘟
# epoch 100, perplexity 11.671487, time 29.22 sec
#  - 只是一起 落的你 已经的的心 我在认上的你美康 把也没你的笑口 绽瓶是心种你无所谓 我没有思想准手 不到
#  - 回忆的你美 还现的人枯你的重要 最后牵着一起口 不想你的外里 我该庆幸的那么 看的你的外后 我该庆幸的那
# epoch 150, perplexity 4.195628, time 43.83 sec
#  - 只是一个问离 不没人下 你在心上 不在江 我几知着美 每o是我的妹妹 妹在个解释很无 嗯 逃得一眼 你怎
#  - 回忆的冰活 看这座人对见过 不有这时成一个冷冲 还乱现下点多 回忆住你和过的歌  我一下手很的美 脱怪他
# epoch 200, perplexity 2.602714, time 59.45 sec
#  - 只是一起 太斗了你的笑容 绽你在一首错想 什凉的你和过相松时 喜欢看你的笑容 环你在一首错想 山笑间 你
#  - 回忆的冰冻 判带两人你的真忆逃能离颗星球 剥落了忧愁 夜光映在你的温柔轻轻诉说 你色多 曾哟下艳么 会在
# epoch 250, perplexity 1.930185, time 74.72 sec
#  - 只是一个 太近了 亡人他 水史爱人花无辈 隐迭了水爱 踩下合面陪上 淋年成绸长 我借你的孤单 今生必怕难
#  - 回忆的冰冻 判若两人 丢给我去承受 想象中 很不同  想象中一切都和后来不同 挣的并事快 但人熟地熟 还
# epoch 300, perplexity 1.700849, time 90.00 sec
#  - 只是一样让太 就没有手着你 多少初也会好你 给不到花的折翼 轰着流手 你止不住眼泪的决堤 还问我观赏 还
#  - 回忆的那么 判若两人 丢给我去承受 想象中 很不同  想象中一切都和 来如得也 如在会上 月下还有 一缕
# 90.33 sec

# %% [markdown]
# ### GRU门控循环单元模型

# %%
start=time.time()
num_epochs, num_steps, batch_size, lr, clipping_theta = 300, 35, 32, 1e2, 1e-2
pred_period, pred_len, prefixes = 50, 50, ['只是', '回忆']
ctx = d2l.try_gpu()
gru_layer = rnn.GRU(num_hiddens)
model = d2l.RNNModel(gru_layer, vocab_size)
d2l.train_and_predict_rnn_gluon(model, num_hiddens, vocab_size, ctx,
                                corpus_indices, idx_to_char, char_to_idx,
                                num_epochs, num_steps, lr, clipping_theta,
                                batch_size, pred_period, pred_len, prefixes)
print('{:.2f} sec'.format(time.time()-start))
# Out:
# epoch 50, perplexity 115.534407, time 26.54 sec
#  - 只是我的妹妹 不是我心你的妹妹 我想你的你的妹妹 我想你的你的妹妹 我想你的你的妹妹 我想你的你的妹妹
#  - 回忆 我想你的你的妹妹 我想你的你的妹妹 我想你的你的妹妹 我想你的你的妹妹 我想你的你的妹妹 我想你的
# epoch 100, perplexity 7.476660, time 59.73 sec
#  - 只是我的妹妹 我在担的你 现在我的错 守在这间 没在心间 叹的小狂丽 你的天上还是一误淡 我的你 已经好
#  - 回忆爱的风 你若只是我的妹妹 我在担心你是否误会 她只是我的妹妹 对这个解释你无所谓 我没有思想准备 看
# epoch 150, perplexity 1.470736, time 93.20 sec
#  - 只是那么让耳 你只是劝我爱的耳柔 我带你带最后有什么 我带我也回也看爱的温柔 还告诉了我 别再来认错 认
#  - 回忆爱头 别说幸福 简人要重 烛声红天雨 涓涓入梦 梦几月 醒几年 往事凄艳 用情浅 两手缘 鹧鸪清怨
# epoch 200, perplexity 1.060944, time 126.37 sec
#  - 只是时光让耳朵变得宽容 如今一个人听歌总是会觉得失落 幻听你在我的耳边轻轻诉说 夜色多温柔 你有多爱我
#  - 回忆爱情电好不住 夏末秋凉里带一点温热 为你解冻冰河为你做一只扑火的飞蛾 没有什么事情是不值得 为你唱这
# epoch 250, perplexity 1.034739, time 159.59 sec
#  - 只是时光让耳朵变得宽容 如今一个人听歌总是会觉得失落 幻听你在我的耳边轻轻诉说 夜色多温柔 你有多爱我
#  - 回忆爱情电是不再 喜末强悠里教一点米八吊钱来跟他折算 他不干 他不干 百年招牌祖祖辈辈流传下来 挣的并不
# epoch 300, perplexity 1.033592, time 192.32 sec
#  - 只是时光让耳朵变得宽容 如今一个人听歌总是会觉得失落 幻听你在我的耳边轻轻诉说 夜色多温柔 你有多爱我
#  - 回忆爱情电是不再你喜目谓 为你用买冰淇淋 天凉就别穿短裙 别再那么淘气 如果有时不那么开心 我愿意将格洛
# 192.72 sec

# %% [markdown]
# ### LSTM 长短期记忆

# %%
num_epochs, num_steps, batch_size, lr, clipping_theta = 300, 35, 32, 1e2, 1e-2
pred_period, pred_len, prefixes = 50, 50, ['只是', '回忆']
ctx = d2l.try_gpu()
start=time.time()
lstm_layer = rnn.LSTM(num_hiddens)
model = d2l.RNNModel(lstm_layer, vocab_size)
d2l.train_and_predict_rnn_gluon(model, num_hiddens, vocab_size, ctx,
                                corpus_indices, idx_to_char, char_to_idx,
                                num_epochs, num_steps, lr, clipping_theta,
                                batch_size, pred_period, pred_len, prefixes)
print('{:.2f} sec'.format(time.time()-start))
# Out:
# epoch 50, perplexity 189.122607, time 23.56 sec
#  - 只是 你的你的你的 我是你的你的 我不你的你 我在你的你的 我不你的你的 我不你的你的 我不你的你的 我
#  - 回忆 我是你的你的 我不你的你 我在你的你的 我不你的你的 我不你的你的 我不你的你的 我不你的你的 我
# epoch 100, perplexity 28.297073, time 60.20 sec
#  - 只是我的妹妹 我想你 爱经有有 真真 你的你 爱的人 嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟嘟
#  - 回忆 如今无 百在心的心丽 我没没象中那么人 你的你 我也有有有你的美落 我没想象中那么人 你的人也 你
# epoch 150, perplexity 4.684039, time 97.98 sec
#  - 只是我怎奈明 我为你无你 现在心间 别灯铁你 谁在你的美丽 花象的你 你在要上有有用 我们咬中 你在爱的
#  - 回忆 如今无伤冰里 又年恐湖暮还还是忆 太觉是我的妹妹 我在担心你是否误会 她只是我的妹妹 我在担心你是
# epoch 200, perplexity 1.789649, time 136.72 sec
#  - 只是我的耳妹 柳个闻瑶琴起舞和一曲 仿佛映当年翩若惊鸿影 谁三言两语撩拨了情意 谁一颦一笑摇曳了星云 纸
#  - 回忆那么情情又情情 不是一个翼翼 总不会你的表惯 你若城去放短裙和 三边里么随你 不来不不不不会真无 我
# epoch 250, perplexity 1.215142, time 174.70 sec
#  - 只是我的耳妹 我想你 那在变里 我为你最这感 你的城府有多深 我爱的有多蠢 不想再问 一无法去恨 毕竟你
#  - 回忆那么情 又带我为意里里互我 一个踏为还过过过 断桥是否下过雪 我望着湖面 水中寒月如雪 指尖轻点融解
# epoch 300, perplexity 1.112617, time 212.46 sec
#  - 只是我望让耳对为得想的如色 却然总是那那真 我有没一寸美莲胡话在 松后后像像快湮灭感桥 上得厅堂人下厨厨
#  - 回忆那么演 柳带我为舞里里互 我努化恢复你 你的好来有 那乐的时在我 何堤如处别一个钟 你给过的温柔 在
# 212.90 sec

# %% [markdown]
# ### 由以上模型的困惑度perplexity可得,GRU门控循环单元的perplexity最小,为1.04左右,所以效果最好
